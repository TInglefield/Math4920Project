# %% [markdown]
# # Import Libraries, Load Data

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
import seaborn as sns
import yfinance as yf
from numpy import linalg as LA
from sklearn.cluster import KMeans
from statsmodels.tsa.stattools import coint
from itertools import combinations
import matplotlib.dates as mdates
from datetime import datetime

# %% [markdown]
# ### Setting up Data

# %%
# # Paths:
price_path = '/Users/tuckeringlefield/Desktop/price_data_from_shardar.csv'
cap_path = '/Users/tuckeringlefield/Desktop/Data_Science/Math_4920/DNR_Data/FinanceData/cap_data_from_shardar.csv'
#price_path = "C:/Users/Owner/school/math4920/price_data_from_shardar.csv"
#cap_path = "C:/Users/Owner/school/math4920/cap_data_from_shardar.csv"

# Reading Data:
prices_df = pd.read_csv(price_path, index_col='date')
caps_df = pd.read_csv(cap_path, index_col='date')

# Drop troubled stock...
prices_df.drop(["MGI", "MDLZ", "DWA", "ICE"], axis=1, inplace=True)
caps_df.drop(["MGI", "MDLZ", "DWA", "ICE"], axis=1, inplace=True)

# %%
# Convert dates to datetime
prices_df.index = pd.to_datetime(prices_df.index)

# Get the initial start and end date
start_date = prices_df.index[0]
end_date = prices_df.index[-1]

# Download additional data:
spy_data = yf.download('SPY', start=start_date, end=end_date, interval='1d')
spy_data = pd.DataFrame(spy_data["Adj Close"])
spy_data.rename({"Adj Close": 'SPY'}, inplace=True, axis=1)

# Set up dataframes:
prices_with_market = prices_df.merge(spy_data, how='left', left_index=True, right_index=True)
# df_diff = prices_with_market.diff().dropna()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Functions

# %% [markdown]
# ## Helper Functions

# %%
# Function to find the top ten largest market cap stocks
def find_top_liquid_stocks(dataframe, date_start, date_end, num_stocks):
    target_date = date_end + 1
    selected_row = caps_df.iloc[target_date]
    selected_row_no_null = selected_row.dropna()
    stocks_list = selected_row_no_null.nlargest(num_stocks).index.tolist()
    return stocks_list

# %%
# Function to filter the DF
def filter_diff_df(dataframe, date_start, date_end, stocks_list):
    desired_columns = stocks_list.copy()
    desired_columns.append("SPY")
    filtered_df = dataframe[desired_columns]
    filtered_df = filtered_df[date_start:date_end].diff()#.dropna()
    filtered_df = filtered_df.dropna()
    return filtered_df

# %%
def filter_df_by_dates(dataframe, date_start, date_end, stocks_list):
    desired_columns = stocks_list.copy()
    desired_columns.append("SPY")
    filtered_df = dataframe[desired_columns]
    filtered_df = filtered_df[date_start:date_end]
    return filtered_df

# %%
# Function to calculate the residuals
def calculate_residuals(df, stocks_list):
    res_df = pd.DataFrame()
    for stk in stocks_list:
        res_df[stk] = df[stk]-df[stk+"_beta"]*df["SPY"]
    return res_df

# %%
# Function to cluster the matrix
def cluster_the_matrix(df, num_clusters):
    A = abs(df.corr().values)
    D = np.diag(A.sum(axis=1))
    L = D - A
    eigenvalues, eigenvectors = LA.eig(L)
    X = eigenvectors[:,:num_clusters]
    kmeans = KMeans(n_clusters=num_clusters, random_state=2, n_init=20).fit(X)

    cluster_dict = {}

    # Iterate over the indices of cluster_list
    for i in range(len(kmeans.labels_)):
        cluster_number = kmeans.labels_[i]
        stock_name = df.columns[i]

        # Check if cluster_number is already a key in the dictionary
        if cluster_number in cluster_dict:
            cluster_dict[cluster_number].append(stock_name)
        else:
            cluster_dict[cluster_number] = [stock_name]

    # Cluster diagram:
    # fig, ax = plt.subplots(1, 1, figsize=(8, 4))
    # scatter = ax.scatter(X[:, 0], X[:, 1], c=kmeans.labels_)
    # unique_labels = {label: idx for idx, label in enumerate(set(kmeans.labels_))}
    # handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=scatter.cmap(scatter.norm(value)), markersize=10)
    #        for value in unique_labels.values()]
    # labels = unique_labels.keys()
    # ax.legend(handles, labels, title="Clusters", loc="best", bbox_to_anchor=(1, 1))
    # ax.set_title(f'K-Means Clustering Results with K={num_clusters}')
    # plt.show()

    return cluster_dict

# %%
# Function to find the cointegrated pairs
def find_cointegrated_pairs(dataframe, cluster_dict, sig_level):
    cointegrated_pairs = []
    for cluster_num, stocks in cluster_dict.items():
      for stock1, stock2 in combinations(stocks, 2):
          pvalue1 = coint(dataframe[stock1], dataframe[stock2])[1]
          pvalue2 = coint(dataframe[stock2], dataframe[stock1])[1]
          if pvalue1 < sig_level and pvalue2 < sig_level:
              cointegrated_pairs.append((stock1, stock2))
    return cointegrated_pairs

# %%
# Function to check on existing pairs
def is_still_cointegrated(dataframe, pair, sig_level):
    stock1 = pair[0]
    stock2 = pair[1]
    pvalue1 = coint(dataframe[stock1], dataframe[stock2])[1]
    pvalue2 = coint(dataframe[stock2], dataframe[stock1])[1]
    if pvalue1 < sig_level and pvalue2 < sig_level:
        return True
    return False

# %%
# weekly function to calculate the beta of the pair
def calculate_beta_for_pair(dataframe, pair):
    asst1 = pair[0]
    asst2 = pair[1]

    train = dataframe[[asst1, asst2]]

    beta = train.cov().iloc[0, 1]/train[asst2].var()
    return math.floor(beta*100)/100

# %%
# Function to calculate the betas
def calculate_betas(dataframe, date_start, date_end, stocks_list):
    # df = dataframe[date_start:date_end]
    beta_values = []
    columns = []

    df_var = dataframe['SPY'].var()

    for stk in stocks_list:
        df_cov = dataframe[[stk, 'SPY']].cov().loc[stk, 'SPY']
        beta = df_cov / df_var
        beta_values.append(beta)
        columns.append(stk + '_beta')
        
    # print(dataframe[stocks_list])

    beta_df = pd.DataFrame([beta_values], columns=columns)
    beta_df.index = dataframe.index[:1]

    # plt.figure(figsize=(12, 4))
    # sns.boxplot(data=beta_df)
    # plt.show()

    return beta_df

# %%
# Function to get the spread data
def get_spread_limits_for_past_months(dataframe, pair, beta):
    asst1 = pair[0]
    asst2 = pair[1]
    asst1_mean = dataframe[asst1].mean() 
    asst2_mean = dataframe[asst2].mean() 
    spread_data = None
    if asst1_mean > asst2_mean:
        spread_data = dataframe[asst1]-beta*dataframe[asst2]
    else:
        spread_data = dataframe[asst2]-beta*dataframe[asst1]
    mean = spread_data.mean()
    std_dev = spread_data.std()
    lower_limit = mean - (2*std_dev)
    upper_limit = mean + (2*std_dev)
    
    return upper_limit, lower_limit, mean

# %% [markdown]
# ## Main Functions

# %%
def monitor_pair_for_day(prices_with_market, window_size, stock_pair, pair_dictionary, current_day, currently_trading_stocks, spread_return_percentages):
    
    if pair_dictionary["current_spread_mean"] is None:
        # Need to find spread mean for past 90 days
        past_window_data = prices_with_market[current_day - window_size : current_day]
        
        # Find new hedge ratio
        pair_dictionary["current_hedge_ratio"] = float(calculate_beta_for_pair(past_window_data, stock_pair))
        
        # Upper, lower limits and mean
        pair_dictionary["spread_upper_limit"], pair_dictionary["spread_lower_limit"], pair_dictionary["current_spread_mean"] = get_spread_limits_for_past_months(past_window_data, stock_pair, float(pair_dictionary["current_hedge_ratio"]))
        
        
        curr_day_spread = prices_with_market[stock_pair[0]].iloc[current_day]-float(pair_dictionary["current_hedge_ratio"])*prices_with_market[stock_pair[1]].iloc[current_day]
        total_investment = prices_with_market[stock_pair[0]].iloc[current_day] + np.abs(float(pair_dictionary["current_hedge_ratio"]))*prices_with_market[stock_pair[1]].iloc[current_day]
        
        if curr_day_spread >= pair_dictionary["spread_upper_limit"]:
            date = prices_with_market.iloc[current_day].name.strftime('%Y-%m-%d')
            pair_dictionary['trade_info']["open_trade_dates"].append((date, "Selling spread", curr_day_spread, total_investment, float(pair_dictionary["current_hedge_ratio"])))
            pair_dictionary["trade_status_message"] = "Currently in trade"
            pair_dictionary["trade_day_spread_position"] = "upper"
            pair_dictionary["currently_trading"] = True
            have_days_to_trade = True
            # Found a trading day, add to list
            currently_trading_stocks.append(stock_pair[0])
            currently_trading_stocks.append(stock_pair[1])
        elif curr_day_spread <= pair_dictionary["spread_lower_limit"]:
            date = prices_with_market.iloc[current_day].name.strftime('%Y-%m-%d')
            pair_dictionary['trade_info']["open_trade_dates"].append((date, "Buying spread", curr_day_spread, total_investment, float(pair_dictionary["current_hedge_ratio"])))
            pair_dictionary["trade_status_message"] = "Currently in trade"
            pair_dictionary["trade_day_spread_position"] = "lower"
            pair_dictionary["currently_trading"] = True
            have_days_to_trade = True    
            # Found a trading day, add to list
            currently_trading_stocks.append(stock_pair[0])
            currently_trading_stocks.append(stock_pair[1])  
    else:
        # Need current day spread
        curr_day_spread = prices_with_market[stock_pair[0]].iloc[current_day]-float(pair_dictionary["current_hedge_ratio"])*prices_with_market[stock_pair[1]].iloc[current_day]
        total_investment = prices_with_market[stock_pair[0]].iloc[current_day] + np.abs(float(pair_dictionary["current_hedge_ratio"]))*prices_with_market[stock_pair[1]].iloc[current_day]

        # Looking for open trading days
        if pair_dictionary["currently_trading"] == False:
            if curr_day_spread >= pair_dictionary["spread_upper_limit"]:
                date = prices_with_market.iloc[current_day].name.strftime('%Y-%m-%d')
                pair_dictionary['trade_info']["open_trade_dates"].append((date, "Selling spread", curr_day_spread, total_investment, float(pair_dictionary["current_hedge_ratio"])))
                pair_dictionary["trade_status_message"] = "Currently in trade"
                pair_dictionary["trade_day_spread_position"] = "upper"
                pair_dictionary["currently_trading"] = True
                have_days_to_trade = True
                # Found a trading day, add to list
                currently_trading_stocks.append(stock_pair[0])
                currently_trading_stocks.append(stock_pair[1])
            elif curr_day_spread <= pair_dictionary["spread_lower_limit"]:
                date = prices_with_market.iloc[current_day].name.strftime('%Y-%m-%d')
                pair_dictionary['trade_info']["open_trade_dates"].append((date, "Buying spread", curr_day_spread, total_investment, float(pair_dictionary["current_hedge_ratio"])))
                pair_dictionary["trade_status_message"] = "Currently in trade"
                pair_dictionary["trade_day_spread_position"] = "lower"
                pair_dictionary["currently_trading"] = True
                have_days_to_trade = True    
                # Found a trading day, add to list
                currently_trading_stocks.append(stock_pair[0])
                currently_trading_stocks.append(stock_pair[1])
        else:
            if (pair_dictionary["trade_day_spread_position"] == "upper" and curr_day_spread <= pair_dictionary["current_spread_mean"]) or (pair_dictionary["trade_day_spread_position"] == "lower" and curr_day_spread >= pair_dictionary["current_spread_mean"]):
                # Close the trade, mean reverted
                # Found a closing day
                date = prices_with_market.iloc[current_day].name.strftime('%Y-%m-%d')
                pair_dictionary['trade_info']["close_trade_dates"].append((date, 'Stocks mean reverted', curr_day_spread))
                # Calculate the spread difference percentage 
                open = pair_dictionary['trade_info']['open_trade_dates'][-1][2]
                close = curr_day_spread
                percent_return = 0
                if pair_dictionary['trade_day_spread_position'] == 'upper':
                    #(open-close)/open
                    percent_return = (open-curr_day_spread)/total_investment *100   
                else:
                    #(close-open)/open
                    percent_return = (curr_day_spread-open)/total_investment *100
                    # appending percentages to list and removing stock pair from currently trading
                percent_formatted = math.floor(percent_return*100)/100
                print(f"Stock pair: {stock_pair}, percentage: {percent_formatted}")
                spread_return_percentages.append(percent_formatted)
                pair_dictionary["trade_status_message"] = "Looking for trading days"
                pair_dictionary["trade_day_spread_position"] = "unknown"
                pair_dictionary["currently_trading"] = False
                have_days_to_trade = True
                # Removed stocks from being traded because they just closed
                currently_trading_stocks.remove(stock_pair[0])
                currently_trading_stocks.remove(stock_pair[1])
        
    return pair_dictionary, spread_return_percentages

# %%
def monitor_pairs(window_size, stock_group_size, stop_after_days):
    global prices_with_market
    currently_trading_stocks = []
    existing_stocks = {}
    currently_monitoring_pairs = []
    spread_return_percentages = []
    
    for day in range(stop_after_days):
        window_start_index = day
        window_end_index = day + window_size
            
        if day % 7 == 0:
            print(f'----------- Weeks Running: {day // 7} --------------------')
            # Find new pairs
            top_liquid_stocks = find_top_liquid_stocks(prices_with_market, window_start_index , window_end_index, stock_group_size)
            liquid_stocks_not_null = []
            window_stock_data = prices_with_market[window_start_index: window_end_index]
            for stock in top_liquid_stocks:
                num_nulls_for_stock = window_stock_data[stock].isnull().sum().item()
                if num_nulls_for_stock == 0:
                    liquid_stocks_not_null.append(stock)  
                    
            # Check if we need to reset hedge ratio and spread mean
            currently_monitoring_pairs_copy = currently_monitoring_pairs.copy()
            for stock_pair in currently_monitoring_pairs_copy:
                if existing_stocks[stock_pair]["currently_trading"] == False:
                    existing_stocks[stock_pair]["current_spread_mean"] = None
                    existing_stocks[stock_pair]["current_hedge_ratio"] = None
                if stock_pair[0] in liquid_stocks_not_null and stock_pair[1] in liquid_stocks_not_null:
                    # Check if pair is still cointegrated
                    if is_still_cointegrated(window_stock_data, stock_pair, 0.05):
                        continue
                    else:
                        current_day_string = prices_with_market.iloc[window_end_index].name.strftime('%Y-%m-%d')
                        if existing_stocks[stock_pair]["currently_trading"]:
                            # Calculate current day spread
                            curr_day_spread = prices_with_market[stock_pair[0]].iloc[window_end_index]-float(existing_stocks[stock_pair]["current_hedge_ratio"])*prices_with_market[stock_pair[1]].iloc[window_end_index]
                            # Close trade due to cointegration
                            existing_stocks[stock_pair]["currently_trading"] = False
                            existing_stocks[stock_pair]['trade_info']["close_trade_dates"].append((current_day_string, 'Stocks are no longer cointegrated', curr_day_spread))
                            # Calculate the spread difference percentage 
                            open = existing_stocks[stock_pair]['trade_info']['open_trade_dates'][-1][2]
                            total_investment = existing_stocks[stock_pair]['trade_info']['open_trade_dates'][-1][-2]
                            if existing_stocks[stock_pair]['trade_day_spread_position'] == 'upper':
                                #(open-close)/open
                                percent_return = ((open-curr_day_spread)/total_investment) *100   
                            else:
                                #(close-open)/open
                                percent_return = ((curr_day_spread-open)/total_investment) *100
                            # appending percentages to list and removing stock pair from currently trading
                            percent_formatted = math.floor(percent_return*100)/100
                            print(f"Stock pair: {stock_pair}, percentage: {percent_formatted}")
                            spread_return_percentages.append(percent_formatted)
                            currently_trading_stocks.remove(stock_pair[0])
                            currently_trading_stocks.remove(stock_pair[1])
        
                        existing_stocks[stock_pair]["should_monitor"] = False
                        existing_stocks[stock_pair]["current_spread_mean"] = None
                        existing_stocks[stock_pair]["current_hedge_ratio"] = None
                        existing_stocks[stock_pair]["is_cointegrated"] = False
                        existing_stocks[stock_pair]["trade_status_message"] = 'Stocks no longer cointegrated'
                        existing_stocks[stock_pair]["monitoring_end_dates"].append(current_day_string)  
                        existing_stocks[stock_pair]["trade_day_spread_position"] = 'unknown'
                        currently_monitoring_pairs.remove(stock_pair)
                else:
                    current_day_string = prices_with_market.iloc[window_end_index].name.strftime('%Y-%m-%d')
                    if existing_stocks[stock_pair]["currently_trading"]:
                        # Calculate current day spread
                        curr_day_spread = prices_with_market[stock_pair[0]].iloc[window_end_index]-float(existing_stocks[stock_pair]["current_hedge_ratio"])*prices_with_market[stock_pair[1]].iloc[window_end_index]
                        # Close trade due to liquidity
                        existing_stocks[stock_pair]["currently_trading"] = False
                        existing_stocks[stock_pair]['trade_info']["close_trade_dates"].append((current_day_string, 'One or more stocks is not liquid enough to trade', curr_day_spread))
                        # Calculate the spread difference percentage 
                        open = existing_stocks[stock_pair]['trade_info']['open_trade_dates'][-1][2]
                        total_investment = existing_stocks[stock_pair]['trade_info']['open_trade_dates'][-1][-2]
                        if existing_stocks[stock_pair]['trade_day_spread_position'] == 'upper':
                            #(open-close)/open
                            percent_return = ((open-curr_day_spread)/total_investment) *100   
                        else:
                            #(close-open)/open
                            percent_return = ((curr_day_spread-open)/total_investment) *100
                        # appending percentages to list and removing stock pair from currently trading
                        percent_formatted = math.floor(percent_return*100)/100
                        print(f"Stock pair: {stock_pair}, percentage: {percent_formatted}")
                        spread_return_percentages.append(percent_formatted)
                        currently_trading_stocks.remove(stock_pair[0])
                        currently_trading_stocks.remove(stock_pair[1])
    
                    existing_stocks[stock_pair]["should_monitor"] = False
                    existing_stocks[stock_pair]["current_spread_mean"] = None
                    existing_stocks[stock_pair]["current_hedge_ratio"] = None
                    existing_stocks[stock_pair]["is_cointegrated"] = None
                    existing_stocks[stock_pair]["trade_status_message"] = 'Stocks not liquid enough to trade'
                    existing_stocks[stock_pair]["monitoring_end_dates"].append(current_day_string)  
                    existing_stocks[stock_pair]["trade_day_spread_position"] = 'unknown'
                    currently_monitoring_pairs.remove(stock_pair)
                        
                                    
            # Clustering
            diff_df = filter_diff_df(prices_with_market, window_start_index , window_end_index, liquid_stocks_not_null)
            window_highly_liquid_stocks_price_df = filter_df_by_dates(prices_with_market, window_start_index , window_end_index, liquid_stocks_not_null)
            beta_df = calculate_betas(diff_df, window_start_index , window_end_index, liquid_stocks_not_null)

            merged_df = diff_df.merge(beta_df, how = 'cross')
            res_df = calculate_residuals(merged_df, liquid_stocks_not_null)
            cluster_dict = cluster_the_matrix(res_df, 3)
            clustered_stock_pairs = find_cointegrated_pairs(window_highly_liquid_stocks_price_df, cluster_dict, 0.05)
            for stock_pair in clustered_stock_pairs:
                # Destructure to check not in existing
                stock1, stock2 = stock_pair
                if stock1 in currently_trading_stocks or stock2 in currently_trading_stocks:
                    continue
                if ((stock1, stock2) not in existing_stocks and (stock2, stock1) not in existing_stocks):
                    # Start monitoring and add to list
                    existing_stocks[stock_pair] = {
                        "is_cointegrated" : True,
                        "should_monitor" : True,
                        "trade_status_message" : "Looking for trading days",
                        "monitoring_start_dates" : [prices_with_market.iloc[window_end_index].name.strftime('%Y-%m-%d')],
                        "monitoring_end_dates" : [],
                        
                        'trade_info' : {
                            "open_trade_dates" : [],
                            "close_trade_dates" : [],
                        },
                        
                        "trade_day_spread_position": "unknown",
                        "current_hedge_ratio": None,
                        "current_spread_mean": None,
                        "spread_upper_limit": None,
                        "spread_lower_limit": None,
                        "currently_trading": False
                    }
                    currently_monitoring_pairs.append(stock_pair)
                else:
                    if (stock1, stock2) in existing_stocks:
                        stock_pair = (stock1, stock2)
                    else:
                        stock_pair = (stock2, stock1)
                    # Check if stock pair was being monitored last week
                    if existing_stocks[stock_pair]["should_monitor"] :
                        continue
                    else:
                        # Stock pair was not being monitored last week, but we should start monitoring
                        existing_stocks[stock_pair]["monitoring_start_dates"].append(prices_with_market.index[window_end_index].strftime('%Y-%m-%d'))
                        existing_stocks[stock_pair]["should_monitor"] = True
                        existing_stocks[stock_pair]["trade_status_message"] = "Looking for trading days"
                        existing_stocks[stock_pair]["is_cointegrated"] = True
                        currently_monitoring_pairs.append(stock_pair)
                        
        # Daily process to check the spreads
        for stock_pair in currently_monitoring_pairs:
            # Check if either of the stocks prices are null:
            if ((pd.isna(prices_with_market[stock_pair[0]].iloc[window_end_index]))or (pd.isna(prices_with_market[stock_pair[1]].iloc[window_end_index]))):
                # are they in a trade?
                if (len(existing_stocks[stock_pair]['trade_info']['open_trade_dates'])>len(existing_stocks[stock_pair]['trade_info']['close_trade_dates'])):
                    # close the trade
                    current_day_string = prices_with_market.iloc[window_end_index].name.strftime('%Y-%m-%d') 
                    # Calculate current day spread
                    prev_day_spread = prices_with_market[stock_pair[0]].iloc[window_end_index - 1]-float(existing_stocks[stock_pair]["current_hedge_ratio"])*prices_with_market[stock_pair[1]].iloc[window_end_index - 1]
                    # Close trade due to liquidity
                    existing_stocks[stock_pair]["currently_trading"] = False
                    existing_stocks[stock_pair]['trade_info']["close_trade_dates"].append((current_day_string, 'Null values', curr_day_spread))
                    # Calculate the spread difference percentage 
                    open = existing_stocks[stock_pair]['trade_info']['open_trade_dates'][-1][2]
                    total_investment = existing_stocks[stock_pair]['trade_info']['open_trade_dates'][-1][-2]
                    if existing_stocks[stock_pair]['trade_day_spread_position'] == 'upper':
                        #(open-close)/open
                        percent_return = ((open-prev_day_spread)/total_investment) *100   
                    else:
                        #(close-open)/open
                        percent_return = ((prev_day_spread-open)/total_investment) *100
                    # appending percentages to list and removing stock pair from currently trading
                    percent_formatted = math.floor(percent_return*100)/100
                    print(f"Stock pair: {stock_pair}, percentage: {percent_formatted}")
                    spread_return_percentages.append(percent_formatted)
                    currently_trading_stocks.remove(stock_pair[0])
                    currently_trading_stocks.remove(stock_pair[1])
                # close out the monitoring period
                existing_stocks[stock_pair]["should_monitor"] = False
                existing_stocks[stock_pair]["current_spread_mean"] = None
                existing_stocks[stock_pair]["current_hedge_ratio"] = None
                existing_stocks[stock_pair]["is_cointegrated"] = None
                existing_stocks[stock_pair]["trade_status_message"] = 'Null values'
                existing_stocks[stock_pair]["monitoring_end_dates"].append(current_day_string)  
                existing_stocks[stock_pair]["trade_day_spread_position"] = 'unknown'
                currently_monitoring_pairs.remove(stock_pair)

            if existing_stocks[stock_pair]["currently_trading"] or (stock_pair[0] not in currently_trading_stocks and stock_pair[1] not in currently_trading_stocks):
                existing_stocks[stock_pair], spread_return_percentages = monitor_pair_for_day(prices_with_market, window_size, stock_pair, existing_stocks[stock_pair], window_end_index, currently_trading_stocks, spread_return_percentages)

    return existing_stocks, spread_return_percentages

# %% [markdown]
# # Running Code

# %%
# Run Main code
import pprint as pprint
num_days_to_run = 1000
window_size_in_days = 500
num_liquid_stocks_to_consider = 30
results, spread_percentages = monitor_pairs(window_size_in_days, num_liquid_stocks_to_consider, num_days_to_run)
pprint.pprint(results)
print(spread_percentages)
# Out:
# ----------- Weeks Running: 0 --------------------
# ----------- Weeks Running: 1 --------------------
# Stock pair: ('INTC', 'DELL1'), percentage: -0.55
# Stock pair: ('ORCL', 'TWX'), percentage: 7.97
# Stock pair: ('EMC1', 'SEBL'), percentage: -7.16
# Stock pair: ('PSFT', 'BIIB'), percentage: 3.27
# ----------- Weeks Running: 2 --------------------
# Stock pair: ('ORCL', 'XLNX'), percentage: 4.45
# ----------- Weeks Running: 3 --------------------
# Stock pair: ('BRCM', 'JAVA1'), percentage: 9.62
# Stock pair: ('EMC1', 'SEBL'), percentage: 0.62
# ----------- Weeks Running: 4 --------------------
# ----------- Weeks Running: 5 --------------------
# Stock pair: ('CSCO', 'XLNX'), percentage: 2.22
# ----------- Weeks Running: 6 --------------------
# Stock pair: ('MSFT', 'NVLS1'), percentage: -11.71
# Stock pair: ('INTC', 'XLNX'), percentage: -5.72
# ----------- Weeks Running: 7 --------------------
# Stock pair: ('ORCL', 'XLNX'), percentage: 2.9
# Stock pair: ('PFE', 'COST'), percentage: -0.43
# Stock pair: ('KLAC', 'WMT'), percentage: -3.88
# ----------- Weeks Running: 8 --------------------
# Stock pair: ('PFE', 'WYE'), percentage: -0.14
# ----------- Weeks Running: 9 --------------------
# Stock pair: ('BRCD', 'KO'), percentage: 0.63
# Stock pair: ('KLAC', 'WMT'), percentage: 2.79
# ----------- Weeks Running: 10 --------------------
# Stock pair: ('PFE', 'WYE'), percentage: 0.0
# ----------- Weeks Running: 11 --------------------
# Stock pair: ('INTC', 'MXIM'), percentage: 6.61
# Stock pair: ('KLAC', 'WMT'), percentage: -0.77
# ----------- Weeks Running: 12 --------------------
# Stock pair: ('CYTC', 'FLEX'), percentage: -6.1
# ----------- Weeks Running: 13 --------------------
# Stock pair: ('MSFT', 'IBM'), percentage: 1.76
# Stock pair: ('CSCO', 'XLNX'), percentage: -3.17
# Stock pair: ('INTC', 'AMGN'), percentage: -0.71
# Stock pair: ('ESRX', 'BGEN'), percentage: 1.68
# Stock pair: ('ADSK', 'MWW'), percentage: -4.6
# ----------- Weeks Running: 14 --------------------
# ----------- Weeks Running: 15 --------------------
# Stock pair: ('INTC', 'XLNX'), percentage: 5.78
# Stock pair: ('BGEN', 'JNJ'), percentage: 8.21
# Stock pair: ('MSFT', 'BIIB'), percentage: -9.59
# ----------- Weeks Running: 16 --------------------
# Stock pair: ('ORCL', 'FLEX'), percentage: 6.35
# Stock pair: ('SEBL', 'MERQ'), percentage: 2.04
# ----------- Weeks Running: 17 --------------------
# Stock pair: ('AMGN', 'TWX'), percentage: -15.43
# Stock pair: ('MSFT', 'HD'), percentage: 1.04
# Stock pair: ('CSCO', 'QLGC'), percentage: 1.11
# Stock pair: ('INTC', 'MXIM'), percentage: 5.17
# Stock pair: ('BGEN', 'JNJ'), percentage: -0.84
# ----------- Weeks Running: 18 --------------------
# Stock pair: ('ORCL', 'XLNX'), percentage: 20.25
# Stock pair: ('AMGN', 'CCU1'), percentage: -5.07
# Stock pair: ('PG', 'WLP1'), percentage: 0.17
# Stock pair: ('UNH', 'GD'), percentage: 1.93
# ----------- Weeks Running: 19 --------------------
# Stock pair: ('KLAC', 'WMT'), percentage: -5.63
# Stock pair: ('MSFT', 'HD'), percentage: 6.45
# Stock pair: ('CSCO', 'QLGC'), percentage: -5.48
# Stock pair: ('ORCL', 'TXN'), percentage: -2.02
# Stock pair: ('AMGN', 'TWX'), percentage: -10.38
# Stock pair: ('PFE', 'EA'), percentage: -8.1
# ----------- Weeks Running: 20 --------------------
# Stock pair: ('AMAT', 'XOM'), percentage: -8.94
# ----------- Weeks Running: 21 --------------------
# Stock pair: ('AMGN', 'IBM'), percentage: 10.88
# Stock pair: ('INTC', 'MXIM'), percentage: 9.91
# ----------- Weeks Running: 22 --------------------
# Stock pair: ('HIB', 'PHA'), percentage: 4.81
# Stock pair: ('JNJ', 'CE1'), percentage: -1.38
# Stock pair: ('KLAC', 'ONE1'), percentage: -3.71
# Stock pair: ('PFE', 'COX'), percentage: 6.95
# ----------- Weeks Running: 23 --------------------
# Stock pair: ('CSCO', 'QLGC'), percentage: 9.84
# ----------- Weeks Running: 24 --------------------
# Stock pair: ('HD', 'WYE'), percentage: 1.84
# Stock pair: ('JNJ', 'CE1'), percentage: 0.4
# Stock pair: ('ORCL', 'LXK'), percentage: -17.08
# ----------- Weeks Running: 25 --------------------
# Stock pair: ('AMGN', 'IBM'), percentage: 0.86
# Stock pair: ('KLAC', 'WMT'), percentage: -1.4
# ----------- Weeks Running: 26 --------------------
# Stock pair: ('INTC', 'MXIM'), percentage: 7.36
# Stock pair: ('PFE', 'HCA1'), percentage: -3.34
# Stock pair: ('AMGN', 'BGEN'), percentage: -1.48
# ----------- Weeks Running: 27 --------------------
# Stock pair: ('DELL1', 'ONE1'), percentage: 2.46
# ----------- Weeks Running: 28 --------------------
# Stock pair: ('AMAT', 'XOM'), percentage: -3.94
# Stock pair: ('HD', 'WYE'), percentage: -0.03
# Stock pair: ('CSCO', 'QLGC'), percentage: 5.03
# Stock pair: ('DELL1', 'WMT'), percentage: 1.69
# Stock pair: ('JNJ', 'FRX1'), percentage: -3.04
# Stock pair: ('KSS', 'ONE1'), percentage: 0.29
# Stock pair: ('TXU', 'FDC1'), percentage: -24.81
# Stock pair: ('QCOM', 'EA'), percentage: 20.43
# ----------- Weeks Running: 29 --------------------
# Stock pair: ('PG', 'WLP1'), percentage: -4.82
# Stock pair: ('MSFT', 'IBM'), percentage: -1.86
# Stock pair: ('AMGN', 'UNH'), percentage: 1.04
# ----------- Weeks Running: 30 --------------------
# Stock pair: ('ORCL', 'PHA'), percentage: -4.79
# Stock pair: ('YHOO', 'DELL1'), percentage: 5.83
# Stock pair: ('AMAT', 'XOM'), percentage: 6.93
# ----------- Weeks Running: 31 --------------------
# Stock pair: ('THC', 'AGN1'), percentage: -22.18
# Stock pair: ('QLGC', 'DELL1'), percentage: 7.38
# ----------- Weeks Running: 32 --------------------
# Stock pair: ('PFE', 'EA'), percentage: 2.94
# Stock pair: ('DELL1', 'WMT'), percentage: -0.73
# Stock pair: ('AMZN', 'MMM'), percentage: 10.88
# ----------- Weeks Running: 33 --------------------
# Stock pair: ('UNH', 'WLP1'), percentage: -1.87
# Stock pair: ('MSFT', 'IBM'), percentage: -1.33
# Stock pair: ('CSCO', 'LEHMQ'), percentage: 1.51
# Stock pair: ('AMAT', 'HD'), percentage: 0.29
# Stock pair: ('TXN', 'XLNX'), percentage: 0.62
# ----------- Weeks Running: 34 --------------------
# Stock pair: ('ORCL', 'QCOM'), percentage: 1.35
# Stock pair: ('UNH', 'PG'), percentage: 0.79
# Stock pair: ('AMAT', 'XOM'), percentage: -4.69
# ----------- Weeks Running: 35 --------------------
# Stock pair: ('NXTL', 'PHA'), percentage: 5.01
# Stock pair: ('INTC', 'MXIM'), percentage: -5.61
# Stock pair: ('PFE', 'EA'), percentage: -7.79
# ----------- Weeks Running: 36 --------------------
# Stock pair: ('MSFT', 'MRK'), percentage: 0.16
# Stock pair: ('AMGN', 'IBM'), percentage: -2.94
# Stock pair: ('QLGC', 'MDT'), percentage: 0.37
# ----------- Weeks Running: 37 --------------------
# Stock pair: ('CSCO', 'EA'), percentage: 0.55
# Stock pair: ('INTC', 'HD'), percentage: 6.27
# Stock pair: ('ORCL', 'QCOM'), percentage: 8.47
# Stock pair: ('MSFT', 'SNPS'), percentage: 7.64
# Stock pair: ('LOW', 'JNJ'), percentage: -2.18
# ----------- Weeks Running: 38 --------------------
# Stock pair: ('DELL1', 'WMT'), percentage: -4.06
# Stock pair: ('INTC', 'WYE'), percentage: 3.57
# ----------- Weeks Running: 39 --------------------
# Stock pair: ('CSCO', 'EA'), percentage: -1.32
# Stock pair: ('YHOO', 'DELL1'), percentage: -1.29
# Stock pair: ('AMZN', 'IGT1'), percentage: -0.05
# ----------- Weeks Running: 40 --------------------
# Stock pair: ('NXTL', 'PHA'), percentage: 2.46
# Stock pair: ('QLGC', 'DELL1'), percentage: 2.76
# Stock pair: ('LVLT', 'RMBS'), percentage: 5.71
# Stock pair: ('INTU', 'BGEN'), percentage: -1.31
# ----------- Weeks Running: 41 --------------------
# Stock pair: ('DELL1', 'MDT'), percentage: 10.81
# Stock pair: ('QCOM', 'WLP1'), percentage: -6.8
# Stock pair: ('UNH', 'PG'), percentage: 0.27
# ----------- Weeks Running: 42 --------------------
# Stock pair: ('INTC', 'WYE'), percentage: 6.59
# Stock pair: ('NVLS1', 'CCU1'), percentage: 1.87
# Stock pair: ('HD', 'XLNX'), percentage: -0.81
# ----------- Weeks Running: 43 --------------------
# Stock pair: ('ORCL', 'AMGN'), percentage: -10.25
# Stock pair: ('NXTL', 'WMT'), percentage: 7.13
# Stock pair: ('CSCO', 'SGP'), percentage: 0.13
# ----------- Weeks Running: 44 --------------------
# Stock pair: ('INTC', 'MXIM'), percentage: -4.48
# Stock pair: ('YHOO', 'PPDI'), percentage: 10.01
# Stock pair: ('NVLS1', 'ADBE'), percentage: 3.23
# ----------- Weeks Running: 45 --------------------
# Stock pair: ('CSCO', 'INTU'), percentage: -2.08
# Stock pair: ('AMZN', 'MMM'), percentage: -1.21
# Stock pair: ('MSFT', 'AGN1'), percentage: 0.87
# Stock pair: ('INTC', 'HD'), percentage: -3.08
# Stock pair: ('DELL1', 'MDT'), percentage: 1.57
# ----------- Weeks Running: 46 --------------------
# Stock pair: ('IBM', 'PFE'), percentage: 6.82
# Stock pair: ('AMAT', 'XOM'), percentage: -4.86
# Stock pair: ('MSFT', 'BGEN'), percentage: -2.59
# Stock pair: ('YHOO', 'HCA1'), percentage: -3.29
# Stock pair: ('INTC', 'MXIM'), percentage: 3.08
# Stock pair: ('CSCO', 'AFFX'), percentage: 14.44
# ----------- Weeks Running: 47 --------------------
# Stock pair: ('HCA1', 'CHZS'), percentage: 4.7
# Stock pair: ('MSFT', 'WLP1'), percentage: -1.38
# Stock pair: ('INTC', 'HD'), percentage: 3.54
# Stock pair: ('AMGN', 'UNH'), percentage: -3.06
# Stock pair: ('DELL1', 'JNJ'), percentage: 2.61
# ----------- Weeks Running: 48 --------------------
# Stock pair: ('AMZN', 'MMM'), percentage: 6.48
# Stock pair: ('INTC', 'WYE'), percentage: -1.27
# ----------- Weeks Running: 49 --------------------
# Stock pair: ('INTC', 'XLNX'), percentage: 1.17
# Stock pair: ('AAPL', 'AMAT'), percentage: 10.95
# ----------- Weeks Running: 50 --------------------
# Stock pair: ('BRCM', 'HD'), percentage: 3.01
# Stock pair: ('MSFT', 'CA1'), percentage: -0.26
# ----------- Weeks Running: 51 --------------------
# Stock pair: ('CSCO', 'PFE'), percentage: 12.87
# Stock pair: ('AMAT', 'XOM'), percentage: 1.3
# Stock pair: ('JNJ', 'ACS'), percentage: 2.67
# ----------- Weeks Running: 52 --------------------
# Stock pair: ('MSFT', 'BGEN'), percentage: -3.81
# Stock pair: ('DELL1', 'LVLT'), percentage: 5.82
# Stock pair: ('INTC', 'WYE'), percentage: -1.54
# Stock pair: ('AMAT', 'BBY'), percentage: -5.9
# Stock pair: ('SIRI', 'VRTS1'), percentage: -0.17
# Stock pair: ('PFE', 'BIIB'), percentage: 0.47
# ----------- Weeks Running: 53 --------------------
# Stock pair: ('NVDA', 'VRTS1'), percentage: -2.01
# ----------- Weeks Running: 54 --------------------
# Stock pair: ('INTC', 'WYE'), percentage: 4.53
# Stock pair: ('CSCO', 'PFE'), percentage: 3.91
# Stock pair: ('AMAT', 'XOM'), percentage: 2.78
# ----------- Weeks Running: 55 --------------------
# Stock pair: ('CSCO', 'EMC1'), percentage: 1.23
# Stock pair: ('WMT', 'JNJ'), percentage: -0.59
# Stock pair: ('BRCM', 'VRTS1'), percentage: 1.49
# Stock pair: ('SGP', 'PFE'), percentage: -0.82
# ----------- Weeks Running: 56 --------------------
# Stock pair: ('DELL1', 'LVLT'), percentage: 8.23
# Stock pair: ('YHOO', 'STJ'), percentage: 1.96
# Stock pair: ('ISIL', 'LU1'), percentage: 6.95
# ----------- Weeks Running: 57 --------------------
# Stock pair: ('INTC', 'HD'), percentage: 3.46
# Stock pair: ('BKNG', 'NVLS1'), percentage: 8.53
# ----------- Weeks Running: 58 --------------------
# Stock pair: ('COST', 'BRCM'), percentage: 1.9
# Stock pair: ('MSFT', 'CEPH'), percentage: 1.98
# Stock pair: ('WMT', 'JNJ'), percentage: -1.95
# Stock pair: ('SNDK', 'GILD'), percentage: 3.49
# ----------- Weeks Running: 59 --------------------
# Stock pair: ('CSCO', 'KKD'), percentage: 2.05
# Stock pair: ('AMAT', 'TGT'), percentage: 6.83
# Stock pair: ('MU', 'BGPTQ'), percentage: 11.6
# ----------- Weeks Running: 60 --------------------
# Stock pair: ('AMAT', 'XOM'), percentage: -3.47
# Stock pair: ('INTC', 'WYE'), percentage: -1.38
# Stock pair: ('TXN', 'HD'), percentage: 1.86
# Stock pair: ('ALTR1', 'FBF'), percentage: -0.87
# ----------- Weeks Running: 61 --------------------
# Stock pair: ('ORCL', 'IBM'), percentage: 0.36
# Stock pair: ('AMZN', 'GPS'), percentage: 7.25
# Stock pair: ('ADVP', 'AMGN'), percentage: -0.28
# Stock pair: ('PFE', 'FLEX'), percentage: 3.47
# ----------- Weeks Running: 62 --------------------
# Stock pair: ('INTC', 'WYE'), percentage: 1.29
# Stock pair: ('AMAT', 'AL1'), percentage: -2.19
# Stock pair: ('HD', 'XL1'), percentage: -0.36
# Stock pair: ('WMT', 'LVLT'), percentage: 0.12
# ----------- Weeks Running: 63 --------------------
# Stock pair: ('BRCM', 'TWX'), percentage: 3.55
# Stock pair: ('AMZN', 'DELL1'), percentage: 1.25
# Stock pair: ('FRX1', 'MSI'), percentage: 2.75
# Stock pair: ('NVLS1', 'CCU1'), percentage: -0.14
# ----------- Weeks Running: 64 --------------------
# Stock pair: ('BHC', 'MEDI1'), percentage: -11.05
# ----------- Weeks Running: 65 --------------------
# Stock pair: ('SCMR', 'MSFT'), percentage: 4.48
# Stock pair: ('FRX1', 'MSI'), percentage: 1.78
# Stock pair: ('SIRI', 'PFE'), percentage: 2.31
# ----------- Weeks Running: 66 --------------------
# Stock pair: ('AMGN', 'CL'), percentage: 2.21
# Stock pair: ('MERQ', 'MACR1'), percentage: -1.92
# Stock pair: ('AWE', 'IBM'), percentage: -5.14
# ----------- Weeks Running: 67 --------------------
# Stock pair: ('ORCL', 'IBM'), percentage: 2.44
# Stock pair: ('FDC1', 'MMC'), percentage: 0.17
# Stock pair: ('LU1', 'TWX'), percentage: 0.29
# Stock pair: ('MSFT', 'BGEN'), percentage: 0.44
# ----------- Weeks Running: 68 --------------------
# Stock pair: ('INTC', 'SCMR'), percentage: 1.07
# Stock pair: ('PFE', 'WYE'), percentage: 4.14
# Stock pair: ('QLGC', 'FBF'), percentage: -1.92
# ----------- Weeks Running: 69 --------------------
# ----------- Weeks Running: 70 --------------------
# Stock pair: ('PFE', 'XOM'), percentage: -2.28
# Stock pair: ('PRDO', 'AMZN'), percentage: 1.78
# ----------- Weeks Running: 71 --------------------
# Stock pair: ('SCMR', 'CSCO'), percentage: -3.85
# Stock pair: ('FDC1', 'MEDI1'), percentage: 3.09
# Stock pair: ('AZO', 'PG'), percentage: 1.19
# ----------- Weeks Running: 72 --------------------
# Stock pair: ('ORCL', 'IBM'), percentage: 4.05
# Stock pair: ('BB', 'CSCO'), percentage: 19.53
# Stock pair: ('JAVA1', 'WYE'), percentage: -1.32
# ----------- Weeks Running: 73 --------------------
# Stock pair: ('MSFT', 'LVLT'), percentage: 9.31
# Stock pair: ('PFE', 'TWX'), percentage: 1.09
# Stock pair: ('SCMR', 'AMZN'), percentage: 6.83
# Stock pair: ('AMAT', 'XOM'), percentage: 1.99
# Stock pair: ('SEBL', 'LU1'), percentage: -1.42
# ----------- Weeks Running: 74 --------------------
# Stock pair: ('CSCO', 'CTX1'), percentage: 5.74
# Stock pair: ('WMT', 'AWE'), percentage: 1.32
# Stock pair: ('BB', 'AXON'), percentage: 2.09
# Stock pair: ('SCMR', 'QLGC'), percentage: -4.44
# ----------- Weeks Running: 75 --------------------
# Stock pair: ('YHOO', 'DELL1'), percentage: 7.14
# Stock pair: ('SCMR', 'SNDK'), percentage: -1.42
# Stock pair: ('MSFT', 'LVLT'), percentage: -4.7
# Stock pair: ('BB', 'ONE1'), percentage: 0.79
# Stock pair: ('CSCO', 'XMSR'), percentage: -1.25
# Stock pair: ('BRCM', 'VRTS1'), percentage: 7.05
# Stock pair: ('NVLS1', 'SLB'), percentage: -8.31
# ----------- Weeks Running: 76 --------------------
# Stock pair: ('SCMR', 'JNPR'), percentage: -2.22
# ----------- Weeks Running: 77 --------------------
# Stock pair: ('LU1', 'PFE'), percentage: -3.63
# Stock pair: ('BB', 'AXON'), percentage: 2.53
# Stock pair: ('AWE', 'XOM'), percentage: 6.32
# Stock pair: ('CSCO', 'LIFE2'), percentage: -0.43
# ----------- Weeks Running: 78 --------------------
# Stock pair: ('RMBS', 'ESINQ'), percentage: 20.65
# Stock pair: ('JNPR', 'CTX1'), percentage: -4.9
# ----------- Weeks Running: 79 --------------------
# Stock pair: ('AAPL', 'XOM'), percentage: 1.78
# Stock pair: ('BB', 'ONE1'), percentage: 1.35
# Stock pair: ('YHOO', 'ASKJ'), percentage: -1.89
# Stock pair: ('KO', 'BIIB'), percentage: 1.18
# ----------- Weeks Running: 80 --------------------
# Stock pair: ('SCMR', 'CSCO'), percentage: -3.95
# Stock pair: ('MSFT', 'WMT'), percentage: -8.92
# Stock pair: ('BRCM', 'AXP'), percentage: 0.18
# Stock pair: ('FDRY', 'MMM'), percentage: -8.47
# Stock pair: ('BRCM', 'FBF'), percentage: -0.98
# ----------- Weeks Running: 81 --------------------
# Stock pair: ('MSFT', 'LVLT'), percentage: 5.99
# Stock pair: ('YHOO', 'AVP'), percentage: -1.55
# Stock pair: ('PFE', 'XOM'), percentage: 0.67
# ----------- Weeks Running: 82 --------------------
# Stock pair: ('AMZN', 'DELL1'), percentage: -2.77
# Stock pair: ('BB', 'ONE1'), percentage: 3.42
# Stock pair: ('SCMR', 'CSCO'), percentage: 3.11
# Stock pair: ('LU1', 'PFE'), percentage: -0.39
# ----------- Weeks Running: 83 --------------------
# Stock pair: ('AAPL', 'BRCM'), percentage: 3.97
# Stock pair: ('DELL1', 'SNDK'), percentage: -1.12
# Stock pair: ('TBI1', 'BB'), percentage: -17.75
# Stock pair: ('YHOO', 'IBM'), percentage: 2.96
# Stock pair: ('AMD', 'TXN'), percentage: -0.87
# ----------- Weeks Running: 84 --------------------
# Stock pair: ('OSIP', 'ABGX'), percentage: 14.62
# Stock pair: ('BB', 'ONE1'), percentage: -3.47
# Stock pair: ('UNH', 'ONXX'), percentage: -1.66
# ----------- Weeks Running: 85 --------------------
# Stock pair: ('CF1', 'BRCM'), percentage: -0.56
# Stock pair: ('OSIP', 'IMCL'), percentage: -5.69
# Stock pair: ('BB', 'SLB'), percentage: 2.8
# Stock pair: ('YHOO', 'IBM'), percentage: 2.06
# ----------- Weeks Running: 86 --------------------
# Stock pair: ('INTC', 'SCMR'), percentage: -0.35
# Stock pair: ('BRCM', 'LEHMQ'), percentage: 2.28
# Stock pair: ('EMC1', 'KLAC'), percentage: -4.61
# ----------- Weeks Running: 87 --------------------
# Stock pair: ('MSFT', 'WYE'), percentage: 1.01
# Stock pair: ('ORCL', 'IBM'), percentage: -1.82
# Stock pair: ('GDT', 'BRCM'), percentage: -0.32
# Stock pair: ('NCRX', 'TXN'), percentage: -5.07
# ----------- Weeks Running: 88 --------------------
# Stock pair: ('CSCO', 'GDT'), percentage: -0.67
# Stock pair: ('ORCL', 'GIS'), percentage: 1.49
# Stock pair: ('MBG1', 'AAPL'), percentage: 3.12
# Stock pair: ('PFE', 'LEHMQ'), percentage: -0.78
# ----------- Weeks Running: 89 --------------------
# Stock pair: ('CYBX', 'CCU1'), percentage: 26.08
# Stock pair: ('SLB', 'LEHMQ'), percentage: 1.4
# ----------- Weeks Running: 90 --------------------
# Stock pair: ('PFE', 'FRX1'), percentage: -0.95
# Stock pair: ('NXTL', 'TTN'), percentage: -3.18
# ----------- Weeks Running: 91 --------------------
# Stock pair: ('AXON', 'KMG1'), percentage: 5.3
# Stock pair: ('ORCL', 'AMGN'), percentage: -5.29
# Stock pair: ('VRTS1', 'AMAT'), percentage: 6.4
# Stock pair: ('CSCO', 'OMC'), percentage: 2.91
# Stock pair: ('EMC1', 'NEM'), percentage: -2.66
# Stock pair: ('NXTL', 'LEHMQ'), percentage: 3.25
# ----------- Weeks Running: 92 --------------------
# Stock pair: ('MSFT', 'MDT'), percentage: 2.33
# Stock pair: ('NFLX', 'BRCM'), percentage: -11.34
# Stock pair: ('PFE', 'MSI'), percentage: -0.76
# Stock pair: ('YHOO', 'SYK'), percentage: 6.64
# Stock pair: ('QCOM', 'BMET'), percentage: 7.04
# ----------- Weeks Running: 93 --------------------
# Stock pair: ('CSCO', 'GDT'), percentage: -4.64
# Stock pair: ('AXON', 'QCOM'), percentage: 3.02
# Stock pair: ('UNH', 'WAT'), percentage: 0.19
# ----------- Weeks Running: 94 --------------------
# Stock pair: ('AMAT', 'UVN'), percentage: -11.67
# Stock pair: ('GPS', 'TEVA'), percentage: 0.81
# ----------- Weeks Running: 95 --------------------
# Stock pair: ('AMAT', 'LOW'), percentage: -3.64
# Stock pair: ('JNPR', 'AXP'), percentage: 1.39
# ----------- Weeks Running: 96 --------------------
# Stock pair: ('AMZN', 'DELL1'), percentage: -3.29
# Stock pair: ('MSFT', 'MDT'), percentage: 0.83
# Stock pair: ('AAPL', 'NUE'), percentage: 5.99
# ----------- Weeks Running: 97 --------------------
# Stock pair: ('CSCO', 'NXTL'), percentage: 1.1
# Stock pair: ('INTC', 'LOW'), percentage: -2.83
# Stock pair: ('TXN', 'EFII'), percentage: 15.14
# Stock pair: ('AMZN', 'ALTR1'), percentage: 0.76
# ----------- Weeks Running: 98 --------------------
# Stock pair: ('AXON', 'PEP'), percentage: 5.24
# Stock pair: ('INTC', 'CYBX'), percentage: -9.72
# Stock pair: ('KO', 'PFE'), percentage: -0.45
# Stock pair: ('AMZN', 'BBY'), percentage: -4.43
# Stock pair: ('LU1', 'TXU'), percentage: -5.97
# ----------- Weeks Running: 99 --------------------
# Stock pair: ('CSCO', 'ALTR1'), percentage: 0.02
# Stock pair: ('AXON', 'QCOM'), percentage: -3.56
# Stock pair: ('TXN', 'IBM'), percentage: -1.91
# ----------- Weeks Running: 100 --------------------
# Stock pair: ('NFLX', 'BRCM'), percentage: -0.02
# Stock pair: ('GIS', 'IBM'), percentage: -0.57
# Stock pair: ('NXTL', 'RT'), percentage: 3.57
# ----------- Weeks Running: 101 --------------------
# Stock pair: ('UNH', 'AAPL'), percentage: -4.48
# Stock pair: ('CVH', 'DELL1'), percentage: -0.84
# Stock pair: ('JNPR', 'PD1'), percentage: -2.25
# ----------- Weeks Running: 102 --------------------
# Stock pair: ('ONXX', 'AXON'), percentage: 1.41
# Stock pair: ('SIRI', 'AXP'), percentage: -2.36
# Stock pair: ('IBM', 'MBOT'), percentage: 3.52
# ----------- Weeks Running: 103 --------------------
# Stock pair: ('IBM', 'CSCO'), percentage: -3.05
# ----------- Weeks Running: 104 --------------------
# Stock pair: ('CSCO', 'MATK'), percentage: 7.83
# Stock pair: ('AMD', 'NXTL'), percentage: 4.49
# Stock pair: ('YHOO', 'ZBRA'), percentage: 1.99
# Stock pair: ('KO', 'PFE'), percentage: -1.26
# Stock pair: ('UNH', 'AET'), percentage: 0.75
# Stock pair: ('SIRI', 'WLP1'), percentage: 21.03
# ----------- Weeks Running: 105 --------------------
# Stock pair: ('AXON', 'QCOM'), percentage: -6.76
# ----------- Weeks Running: 106 --------------------
# Stock pair: ('ORCL', 'CASC'), percentage: 4.62
# Stock pair: ('QCOM', 'MBG1'), percentage: 0.02
# ----------- Weeks Running: 107 --------------------
# Stock pair: ('GEN', 'QCOM'), percentage: -11.85
# ----------- Weeks Running: 108 --------------------
# Stock pair: ('VRTS1', 'ADLR'), percentage: 2.85
# ----------- Weeks Running: 109 --------------------
# ----------- Weeks Running: 110 --------------------
# Stock pair: ('NXTL', 'GDT'), percentage: -2.97
# Stock pair: ('MSFT', 'DELL1'), percentage: -1.29
# Stock pair: ('AXON', 'QCOM'), percentage: -8.09
# Stock pair: ('HAL', 'SBUX'), percentage: -3.12
# Stock pair: ('JNJ', 'WOLF'), percentage: -0.45
# ----------- Weeks Running: 111 --------------------
# ----------- Weeks Running: 112 --------------------
# Stock pair: ('BB', 'XOM'), percentage: -13.48
# Stock pair: ('AMZN', 'MERQ'), percentage: -10.05
# Stock pair: ('INTC', 'CYBX'), percentage: -23.64
# Stock pair: ('JNPR', 'AXP'), percentage: -0.39
# ----------- Weeks Running: 113 --------------------
# Stock pair: ('G1', 'KMG1'), percentage: -9.83
# ----------- Weeks Running: 114 --------------------
# Stock pair: ('QCOM', 'PG'), percentage: -2.81
# Stock pair: ('G1', 'XOM'), percentage: -0.59
# Stock pair: ('HD', 'WB1'), percentage: -0.39
# ----------- Weeks Running: 115 --------------------
# ----------- Weeks Running: 116 --------------------
# Stock pair: ('YHOO', 'BB'), percentage: 7.91
# ----------- Weeks Running: 117 --------------------
# Stock pair: ('AAPL', 'JNJ'), percentage: -1.37
# Stock pair: ('QCOM', 'AXP'), percentage: -1.54
# ----------- Weeks Running: 118 --------------------
# Stock pair: ('KMG1', 'VLO'), percentage: 6.62
# ----------- Weeks Running: 119 --------------------
# Stock pair: ('AAPL', 'JNJ'), percentage: 0.55
# Stock pair: ('AMGN', 'WYE'), percentage: -0.42
# ----------- Weeks Running: 120 --------------------
# Stock pair: ('AAPL', 'UST1'), percentage: 11.61
# Stock pair: ('LXK', 'AMGN'), percentage: 1.97
# Stock pair: ('KMG1', 'PCO1'), percentage: 2.18
# ----------- Weeks Running: 121 --------------------
# Stock pair: ('DELL1', 'EA'), percentage: 3.07
# Stock pair: ('XOM', 'JNJ'), percentage: -1.65
# Stock pair: ('WFM', 'GPRO1'), percentage: 11.21
# Stock pair: ('KMG1', 'VLO'), percentage: 6.4
# ----------- Weeks Running: 122 --------------------
# Stock pair: ('DELL1', 'HD'), percentage: 2.51
# ----------- Weeks Running: 123 --------------------
# Stock pair: ('KMG1', 'PCO1'), percentage: -1.1
# ----------- Weeks Running: 124 --------------------
# Stock pair: ('XOM', 'JNJ'), percentage: 3.5
# ----------- Weeks Running: 125 --------------------
# Stock pair: ('ORCL', 'EMC1'), percentage: 0.82
# Stock pair: ('NXTL', 'LEHMQ'), percentage: -2.01
# Stock pair: ('PD1', 'BSC1'), percentage: -1.35
# Stock pair: ('VLO', 'TOL'), percentage: 1.79
# Stock pair: ('G1', 'PCO1'), percentage: -2.71
# ----------- Weeks Running: 126 --------------------
# Stock pair: ('TOL', 'UCL1'), percentage: -0.49
# ----------- Weeks Running: 127 --------------------
# Stock pair: ('XOM', 'JNJ'), percentage: 0.32
# Stock pair: ('KMG1', 'VLO'), percentage: -0.01
# ----------- Weeks Running: 128 --------------------
# Stock pair: ('IBM', 'KRB'), percentage: -0.14
# Stock pair: ('QCOM', 'PG'), percentage: 1.26
# ----------- Weeks Running: 129 --------------------
# Stock pair: ('YHOO', 'BB'), percentage: 4.69
# Stock pair: ('HAL', 'UNH'), percentage: 1.85
# ----------- Weeks Running: 130 --------------------
# Stock pair: ('CSCO', 'DELL1'), percentage: -9.24
# Stock pair: ('VLO', 'ANF'), percentage: 8.53
# ----------- Weeks Running: 131 --------------------
# Stock pair: ('DELL1', 'HD'), percentage: -0.2
# Stock pair: ('DJ', 'CVX'), percentage: -0.25
# ----------- Weeks Running: 132 --------------------
# Stock pair: ('DELL1', 'PFE'), percentage: -1.13
# Stock pair: ('CSCO', 'ADBE'), percentage: -0.7
# Stock pair: ('XOM', 'JNJ'), percentage: 1.69
# Stock pair: ('KMG1', 'VLO'), percentage: -0.03
# Stock pair: ('QCOM', 'PG'), percentage: -0.61
# ----------- Weeks Running: 133 --------------------
# ----------- Weeks Running: 134 --------------------
# Stock pair: ('MSFT', 'YHOO'), percentage: -2.77
# ----------- Weeks Running: 135 --------------------
# Stock pair: ('MSFT', 'HD'), percentage: 0.93
# ----------- Weeks Running: 136 --------------------
# Stock pair: ('QCOM', 'PG'), percentage: -0.97
# Stock pair: ('KMG1', 'VLO'), percentage: -1.41
# ----------- Weeks Running: 137 --------------------
# Stock pair: ('MSFT', 'YHOO'), percentage: -3.12
# Stock pair: ('AAPL', 'TXU'), percentage: 11.32
# ----------- Weeks Running: 138 --------------------
# Stock pair: ('YHOO', 'BB'), percentage: -5.58
# ----------- Weeks Running: 139 --------------------
# ----------- Weeks Running: 140 --------------------
# Stock pair: ('VLO', 'SLB'), percentage: -6.02
# Stock pair: ('CSCO', 'YHOO'), percentage: 3.87
# Stock pair: ('QCOM', 'PG'), percentage: -1.25
# Stock pair: ('CVX', 'WFTIQ'), percentage: -0.87
# Stock pair: ('ORCL', 'EMC1'), percentage: -1.15
# ----------- Weeks Running: 141 --------------------
# Stock pair: ('CSCO', 'COO'), percentage: -6.65
# Stock pair: ('APCS', 'ADSK'), percentage: -1.08
# ----------- Weeks Running: 142 --------------------
# Stock pair: ('SCMR', 'BB'), percentage: 0.45
# {('AAPL', 'AMAT'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2003-05-14'],
#                     'monitoring_start_dates': ['2003-05-05'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 6.600843685435929,
#                     'spread_upper_limit': 21.156296754564075,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2003-05-14',
#                                                           'One or more stocks '
#                                                           'is not liquid '
#                                                           'enough to trade',
#                                                           0.17061000000000004)],
#                                    'open_trade_dates': [('2003-05-05',
#                                                          'Buying spread',
#                                                          0.1318,
#                                                          0.35419999999999996,
#                                                          0.01)]},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('AAPL', 'BRCM'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2004-04-23'],
#                     'monitoring_start_dates': ['2004-04-14'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 3.4278925403068925,
#                     'spread_upper_limit': 26.373435459693106,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2004-04-23',
#                                                           'One or more stocks '
#                                                           'is not liquid '
#                                                           'enough to trade',
#                                                           0.419)],
#                                    'open_trade_dates': [('2004-04-14',
#                                                          'Buying spread',
#                                                          0.403,
#                                                          0.403,
#                                                          0.0)]},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('AAPL', 'JNJ'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2005-04-05',
#                                             '2005-04-25',
#                                             '2005-05-13',
#                                             '2005-06-14',
#                                             '2005-07-14'],
#                    'monitoring_start_dates': ['2005-03-24',
#                                               '2005-04-14',
#                                               '2005-05-04',
#                                               '2005-05-24',
#                                               '2005-06-23'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 25.452724361698067,
#                    'spread_upper_limit': 38.831810198301945,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2005-04-05',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          -1.9710400000000001),
#                                                         ('2005-04-25',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          -2.0979600000000005)],
#                                   'open_trade_dates': [('2005-03-24',
#                                                         'Buying spread',
#                                                         -1.90984,
#                                                         4.48184,
#                                                         0.08),
#                                                        ('2005-04-14',
#                                                         'Buying spread',
#                                                         -2.12232,
#                                                         4.3783199999999995,
#                                                         0.08)]},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('AAPL', 'NUE'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2004-09-02'],
#                    'monitoring_start_dates': ['2004-08-24'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 4.012231286215151,
#                    'spread_upper_limit': 10.537431753784848,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2004-09-02',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          0.08688000000000007)],
#                                   'open_trade_dates': [('2004-08-24',
#                                                         'Buying spread',
#                                                         0.03064,
#                                                         0.93736,
#                                                         0.04)]},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('AAPL', 'TXU'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': False,
#                    'monitoring_end_dates': ['2005-10-21'],
#                    'monitoring_start_dates': ['2005-10-03'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 0.9053465356670642,
#                    'spread_upper_limit': 49.54277738433294,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2005-10-21',
#                                                          'Stocks are no longer '
#                                                          'cointegrated',
#                                                          0.37595000000000023)],
#                                   'open_trade_dates': [('2005-10-03',
#                                                         'Buying spread',
#                                                         0.002889999999999837,
#                                                         3.29311,
#                                                         0.03)]},
#                    'trade_status_message': 'Stocks no longer cointegrated'},
#  ('AAPL', 'UST1'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2005-05-04'],
#                     'monitoring_start_dates': ['2005-04-25'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 19.46402073282109,
#                     'spread_upper_limit': 43.643412667178914,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2005-05-04',
#                                                           'One or more stocks '
#                                                           'is not liquid '
#                                                           'enough to trade',
#                                                           -0.7792000000000003)],
#                                    'open_trade_dates': [('2005-04-25',
#                                                          'Buying spread',
#                                                          -1.1756000000000004,
#                                                          3.4136000000000006,
#                                                          0.05)]},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('AAPL', 'XOM'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2003-05-14', '2004-03-15'],
#                    'monitoring_start_dates': ['2003-05-05', '2004-03-04'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 15.823353732708973,
#                    'spread_upper_limit': 21.789092507291024,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2004-03-15',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          -0.2546599999999999)],
#                                   'open_trade_dates': [('2004-03-04',
#                                                         'Buying spread',
#                                                         -0.27318,
#                                                         1.03518,
#                                                         0.03)]},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('ADBE', 'INTU'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2003-03-25'],
#                     'monitoring_start_dates': ['2003-03-14'],
#                     'should_monitor': False,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('ADBE', 'LU1'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2002-09-23'],
#                    'monitoring_start_dates': ['2002-09-12'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 3.7038432050623484,
#                    'spread_upper_limit': 19.80064543493765,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('ADSK', 'MWW'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2002-05-14'],
#                    'monitoring_start_dates': ['2002-05-03'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 21.476038761493225,
#                    'spread_upper_limit': 76.99691547850676,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2002-05-14',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          9.857)],
#                                   'open_trade_dates': [('2002-05-03',
#                                                         'Buying spread',
#                                                         10.33156,
#                                                         10.33156,
#                                                         -0.08)]},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('ADVP', 'AMGN'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2003-09-12'],
#                     'monitoring_start_dates': ['2003-09-03'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 11.101349850448141,
#                     'spread_upper_limit': 25.918849909551863,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2003-09-12',
#                                                           'One or more stocks '
#                                                           'is not liquid '
#                                                           'enough to trade',
#                                                           10.013460000000002)],
#                                    'open_trade_dates': [('2003-09-09',
#                                                          'Buying spread',
#                                                          10.24398,
#                                                          82.57602,
#                                                          0.74)]},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('AET', 'BRCM'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2004-04-23'],
#                    'monitoring_start_dates': ['2004-04-14'],
#                    'should_monitor': False,
#                    'spread_lower_limit': None,
#                    'spread_upper_limit': None,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('AGN1', 'JAVA1'): {'current_hedge_ratio': None,
#                      'current_spread_mean': None,
#                      'currently_trading': False,
#                      'is_cointegrated': None,
#                      'monitoring_end_dates': ['2002-11-11'],
#                      'monitoring_start_dates': ['2002-10-31'],
#                      'should_monitor': False,
#                      'spread_lower_limit': None,
#                      'spread_upper_limit': None,
#                      'trade_day_spread_position': 'unknown',
#                      'trade_info': {'close_trade_dates': [],
#                                     'open_trade_dates': []},
#                      'trade_status_message': 'Stocks not liquid enough to '
#                                              'trade'},
#  ('AGN1', 'KLAC'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2002-03-05', '2002-04-15'],
#                     'monitoring_start_dates': ['2002-02-22', '2002-04-04'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 39.52698613973274,
#                     'spread_upper_limit': 54.13357942026725,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('AGN1', 'NXTL'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2002-11-11'],
#                     'monitoring_start_dates': ['2002-10-31'],
#                     'should_monitor': False,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('AGN1', 'ORCL'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2002-11-11',
#                                              '2003-01-02',
#                                              '2003-04-03',
#                                              '2003-04-24'],
#                     'monitoring_start_dates': ['2002-10-31',
#                                                '2002-12-20',
#                                                '2003-03-25',
#                                                '2003-04-14'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 14.99886492009444,
#                     'spread_upper_limit': 25.052790279905558,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('AGN1', 'QCOM'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2002-11-11',
#                                              '2003-01-02',
#                                              '2003-04-03'],
#                     'monitoring_start_dates': ['2002-10-31',
#                                                '2002-12-20',
#                                                '2003-03-25'],
#                     'should_monitor': False,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('AGN1', 'TWX'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2003-04-03'],
#                    'monitoring_start_dates': ['2003-03-25'],
#                    'should_monitor': False,
#                    'spread_lower_limit': None,
#                    'spread_upper_limit': None,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('AGN1', 'UNH'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2002-11-11'],
#                    'monitoring_start_dates': ['2002-10-31'],
#                    'should_monitor': False,
#                    'spread_lower_limit': None,
#                    'spread_upper_limit': None,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('AGN1', 'VRTS1'): {'current_hedge_ratio': None,
#                      'current_spread_mean': None,
#                      'currently_trading': False,
#                      'is_cointegrated': None,
#                      'monitoring_end_dates': ['2002-11-11'],
#                      'monitoring_start_dates': ['2002-10-31'],
#                      'should_monitor': False,
#                      'spread_lower_limit': None,
#                      'spread_upper_limit': None,
#                      'trade_day_spread_position': 'unknown',
#                      'trade_info': {'close_trade_dates': [],
#                                     'open_trade_dates': []},
#                      'trade_status_message': 'Stocks not liquid enough to '
# ...
#                      'monitoring_end_dates': ['2004-04-14'],
#                      'monitoring_start_dates': ['2004-04-02'],
#                      'should_monitor': False,
#                      'spread_lower_limit': -6.32745897084806,
#                      'spread_upper_limit': 59.73392657084807,
#                      'trade_day_spread_position': 'unknown',
#                      'trade_info': {'close_trade_dates': [],
#                                     'open_trade_dates': []},
#                      'trade_status_message': 'Stocks not liquid enough to '
#                                              'trade'},
#  ('YHOO', 'ORCL'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2004-03-04'],
#                     'monitoring_start_dates': ['2004-02-24'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -23.85138856867653,
#                     'spread_upper_limit': -7.680184911323465,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('YHOO', 'PG'): {'current_hedge_ratio': None,
#                   'current_spread_mean': None,
#                   'currently_trading': False,
#                   'is_cointegrated': False,
#                   'monitoring_end_dates': ['2005-09-13'],
#                   'monitoring_start_dates': ['2005-08-23'],
#                   'should_monitor': False,
#                   'spread_lower_limit': -88.64728815239289,
#                   'spread_upper_limit': -23.624423567607124,
#                   'trade_day_spread_position': 'unknown',
#                   'trade_info': {'close_trade_dates': [],
#                                  'open_trade_dates': []},
#                   'trade_status_message': 'Stocks no longer cointegrated'},
#  ('YHOO', 'PPDI'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2003-03-25'],
#                     'monitoring_start_dates': ['2003-03-14'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 4.948696413166889,
#                     'spread_upper_limit': 11.084564506833111,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2003-03-25',
#                                                           'One or more stocks '
#                                                           'is not liquid '
#                                                           'enough to trade',
#                                                           6.333760000000001)],
#                                    'open_trade_dates': [('2003-03-14',
#                                                          'Buying spread',
#                                                          4.735970000000001,
#                                                          15.95403,
#                                                          0.49)]},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('YHOO', 'QLGC'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2002-10-31'],
#                     'monitoring_start_dates': ['2002-10-11'],
#                     'should_monitor': False,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('YHOO', 'RMBS'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2004-03-04'],
#                     'monitoring_start_dates': ['2004-02-12'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -4.1733633880927785,
#                     'spread_upper_limit': 15.711189188092778,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('YHOO', 'STJ'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2003-07-24'],
#                    'monitoring_start_dates': ['2003-07-03'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 8.150890357981487,
#                    'spread_upper_limit': 15.122636202018514,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2003-07-24',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          -0.02120000000000033)],
#                                   'open_trade_dates': [('2003-07-03',
#                                                         'Buying spread',
#                                                         -0.7218799999999987,
#                                                         35.57188,
#                                                         0.72)]},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('YHOO', 'SYK'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2004-07-26'],
#                    'monitoring_start_dates': ['2004-07-15'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 2.113297776020099,
#                    'spread_upper_limit': 18.865800943979906,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2004-07-26',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          -19.348959999999998)],
#                                   'open_trade_dates': [('2004-07-15',
#                                                         'Buying spread',
#                                                         -25.03664,
#                                                         85.53664,
#                                                         1.24)]},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('YHOO', 'TXU'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2004-09-23'],
#                    'monitoring_start_dates': ['2004-09-14'],
#                    'should_monitor': False,
#                    'spread_lower_limit': -9.451480690484999,
#                    'spread_upper_limit': 10.419852250484997,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('YHOO', 'UNH'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': False,
#                    'monitoring_end_dates': ['2004-11-11'],
#                    'monitoring_start_dates': ['2004-11-02'],
#                    'should_monitor': False,
#                    'spread_lower_limit': -45.46242670135406,
#                    'spread_upper_limit': 7.088388141354056,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks no longer cointegrated'},
#  ('YHOO', 'ZBRA'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2004-11-22'],
#                     'monitoring_start_dates': ['2004-11-11'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 15.119563228183235,
#                     'spread_upper_limit': 36.81556429181677,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2004-11-22',
#                                                           'One or more stocks '
#                                                           'is not liquid '
#                                                           'enough to trade',
#                                                           -0.9899999999999949)],
#                                    'open_trade_dates': [('2004-11-11',
#                                                          'Buying spread',
#                                                          -2.5516000000000005,
#                                                          78.13159999999999,
#                                                          0.72)]},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('ZBH', 'BRCM'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2004-07-26'],
#                    'monitoring_start_dates': ['2004-07-15'],
#                    'should_monitor': False,
#                    'spread_lower_limit': None,
#                    'spread_upper_limit': None,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('ZBH', 'MSI'): {'current_hedge_ratio': None,
#                   'current_spread_mean': None,
#                   'currently_trading': False,
#                   'is_cointegrated': None,
#                   'monitoring_end_dates': ['2004-07-26'],
#                   'monitoring_start_dates': ['2004-07-15'],
#                   'should_monitor': False,
#                   'spread_lower_limit': None,
#                   'spread_upper_limit': None,
#                   'trade_day_spread_position': 'unknown',
#                   'trade_info': {'close_trade_dates': [],
#                                  'open_trade_dates': []},
#                   'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('ZBH', 'QCOM'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2004-07-26'],
#                    'monitoring_start_dates': ['2004-07-15'],
#                    'should_monitor': False,
#                    'spread_lower_limit': -5.8740031019684285,
#                    'spread_upper_limit': 10.820140101968429,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('ZBRA', 'AET'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2004-11-22'],
#                    'monitoring_start_dates': ['2004-11-11'],
#                    'should_monitor': False,
#                    'spread_lower_limit': None,
#                    'spread_upper_limit': None,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks not liquid enough to trade'}}
# [-0.55, 7.97, -7.16, 3.27, 4.45, 9.62, 0.62, 2.22, -11.71, -5.72, 2.9, -0.43, -3.88, -0.14, 0.63, 2.79, 0.0, 6.61, -0.77, -6.1, 1.76, -3.17, -0.71, 1.68, -4.6, 5.78, 8.21, -9.59, 6.35, 2.04, -15.43, 1.04, 1.11, 5.17, -0.84, 20.25, -5.07, 0.17, 1.93, -5.63, 6.45, -5.48, -2.02, -10.38, -8.1, -8.94, 10.88, 9.91, 4.81, -1.38, -3.71, 6.95, 9.84, 1.84, 0.4, -17.08, 0.86, -1.4, 7.36, -3.34, -1.48, 2.46, -3.94, -0.03, 5.03, 1.69, -3.04, 0.29, -24.81, 20.43, -4.82, -1.86, 1.04, -4.79, 5.83, 6.93, -22.18, 7.38, 2.94, -0.73, 10.88, -1.87, -1.33, 1.51, 0.29, 0.62, 1.35, 0.79, -4.69, 5.01, -5.61, -7.79, 0.16, -2.94, 0.37, 0.55, 6.27, 8.47, 7.64, -2.18, -4.06, 3.57, -1.32, -1.29, -0.05, 2.46, 2.76, 5.71, -1.31, 10.81, -6.8, 0.27, 6.59, 1.87, -0.81, -10.25, 7.13, 0.13, -4.48, 10.01, 3.23, -2.08, -1.21, 0.87, -3.08, 1.57, 6.82, -4.86, -2.59, -3.29, 3.08, 14.44, 4.7, -1.38, 3.54, -3.06, 2.61, 6.48, -1.27, 1.17, 10.95, 3.01, -0.26, 12.87, 1.3, 2.67, -3.81, 5.82, -1.54, -5.9, -0.17, 0.47, -2.01, 4.53, 3.91, 2.78, 1.23, -0.59, 1.49, -0.82, 8.23, 1.96, 6.95, 3.46, 8.53, 1.9, 1.98, -1.95, 3.49, 2.05, 6.83, 11.6, -3.47, -1.38, 1.86, -0.87, 0.36, 7.25, -0.28, 3.47, 1.29, -2.19, -0.36, 0.12, 3.55, 1.25, 2.75, -0.14, -11.05, 4.48, 1.78, 2.31, 2.21, -1.92, -5.14, 2.44, 0.17, 0.29, 0.44, 1.07, 4.14, -1.92, -2.28, 1.78, -3.85, 3.09, 1.19, 4.05, 19.53, -1.32, 9.31, 1.09, 6.83, 1.99, -1.42, 5.74, 1.32, 2.09, -4.44, 7.14, -1.42, -4.7, 0.79, -1.25, 7.05, -8.31, -2.22, -3.63, 2.53, 6.32, -0.43, 20.65, -4.9, 1.78, 1.35, -1.89, 1.18, -3.95, -8.92, 0.18, -8.47, -0.98, 5.99, -1.55, 0.67, -2.77, 3.42, 3.11, -0.39, 3.97, -1.12, -17.75, 2.96, -0.87, 14.62, -3.47, -1.66, -0.56, -5.69, 2.8, 2.06, -0.35, 2.28, -4.61, 1.01, -1.82, -0.32, -5.07, -0.67, 1.49, 3.12, -0.78, 26.08, 1.4, -0.95, -3.18, 5.3, -5.29, 6.4, 2.91, -2.66, 3.25, 2.33, -11.34, -0.76, 6.64, 7.04, -4.64, 3.02, 0.19, -11.67, 0.81, -3.64, 1.39, -3.29, 0.83, 5.99, 1.1, -2.83, 15.14, 0.76, 5.24, -9.72, -0.45, -4.43, -5.97, 0.02, -3.56, -1.91, -0.02, -0.57, 3.57, -4.48, -0.84, -2.25, 1.41, -2.36, 3.52, -3.05, 7.83, 4.49, 1.99, -1.26, 0.75, 21.03, -6.76, 4.62, 0.02, -11.85, 2.85, -2.97, -1.29, -8.09, -3.12, -0.45, -13.48, -10.05, -23.64, -0.39, -9.83, -2.81, -0.59, -0.39, 7.91, -1.37, -1.54, 6.62, 0.55, -0.42, 11.61, 1.97, 2.18, 3.07, -1.65, 11.21, 6.4, 2.51, -1.1, 3.5, 0.82, -2.01, -1.35, 1.79, -2.71, -0.49, 0.32, -0.01, -0.14, 1.26, 4.69, 1.85, -9.24, 8.53, -0.2, -0.25, -1.13, -0.7, 1.69, -0.03, -0.61, -2.77, 0.93, -0.97, -1.41, -3.12, 11.32, -5.58, -6.02, 3.87, -1.25, -0.87, -1.15, -6.65, -1.08, 0.45]

# %%
print(f'Mean: {np.mean(spread_percentages)}')
print(f'Sum: {np.sum(spread_percentages)}')
# Out:
# Mean: 0.5251898734177215
# Sum: 207.45

# %% [markdown]
# # Visualization

# %%
def construct_periods(start_dates, end_dates):
    periods = []

    min_length = min(len(start_dates), len(end_dates))

    # Pair each start date with the corresponding end date
    for i in range(min_length):
        periods.append((start_dates[i], end_dates[i]))

    # Handle cases where the lists are of unequal length
    if len(start_dates) > len(end_dates):
        # If there are more start dates, pair the remaining ones with None (or a placeholder)
        for j in range(min_length, len(start_dates)):
            periods.append((start_dates[j], None))
    elif len(end_dates) > len(start_dates):
        # If there are more end dates, pair the remaining ones with the last start date
        for j in range(min_length, len(end_dates)):
            periods.append((start_dates[-1], end_dates[j]))

    return periods

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
import pprint

def print_overall_display(pairs_dictionary, days_ran):
    global prices_with_market

    # Function to convert date strings to datetime objects
    def str_to_date(date_str):
        return datetime.strptime(date_str, '%Y-%m-%d')

    # Filter out keys with no periods or events
    filtered_data = pairs_dictionary

    num_pairs = len(filtered_data)
    num_needed_plots = 0
    if num_pairs % 20 != 0:
        num_needed_plots = num_pairs // 20 + 1
    else:
        num_needed_plots = num_pairs // 20

    # Sort the pairs into chunks for printing 
    indexing_var = 0
    keys = list(filtered_data.keys())
    plotting_dict = {}
    for plot in range(num_needed_plots):
        plotting_dict[f'Plot_{plot+1}'] = []
        for j in range(20):
            if indexing_var >= num_pairs:  # Fix for the off-by-one error
                break
            plotting_dict[f'Plot_{plot+1}'].append(keys[indexing_var])
            indexing_var += 1

    # Iterate over the plotting_dict to create plots
    for plot_name, pairs in plotting_dict.items():
        fig, ax = plt.subplots(figsize=(15, 10))  # Adjust the size as needed
        print(f"Creating {plot_name} with pairs: {pairs}")

        # Get the data for the current set of pairs
        chunk_data = [(key, filtered_data[key]) for key in pairs if key in filtered_data]

        # Iterate over the chunk data to plot
        for idx, (key, value) in enumerate(chunk_data):
            label = f"{key[0]}-{key[1]}"

            # Extract monitoring periods
            periods_start = [str_to_date(date) for date in value['monitoring_start_dates']]
            periods_end = [str_to_date(date) for date in value['monitoring_end_dates']]
            periods = construct_periods(periods_start, periods_end)

            # Plot each period as a line
            for start, end in periods:
                if end is None:
                    # Move 'days_ran' rows forward from the start date to determine the end date
                    start_index = prices_with_market.index.get_loc(start.strftime('%Y-%m-%d'))
                    end_index = start_index + days_ran

                    # Ensure end_index does not exceed the length of the DataFrame
                    if end_index >= len(prices_with_market):
                        end_index = len(prices_with_market) - 1

                    end = prices_with_market.index[end_index]  # Get the string date at end_index
                else:
                    # Convert end to string format for consistency
                    end = end.strftime('%Y-%m-%d')

                ax.plot([start, end], [idx, idx], color='black')

            # Plot open trade dates as green dots
            open_trade_dates = [(str_to_date(date_info[0]), date_info[1], date_info[2], date_info[3], date_info[4]) 
                                for date_info in value['trade_info']['open_trade_dates']]

            if open_trade_dates:
                open_trade_dates_only = [date_info[0] for date_info in open_trade_dates]
                ax.plot(open_trade_dates_only, [idx] * len(open_trade_dates_only), 'o', color='green', label='Open Trade Dates' if idx == 0 else "")

            # Plot close trade dates as red dots
            close_trade_dates = [(str_to_date(date_info[0]), date_info[1], date_info[2]) 
                                 for date_info in value['trade_info']['close_trade_dates']]

            if close_trade_dates:
                close_trade_dates_only = [date_info[0] for date_info in close_trade_dates]
                ax.plot(close_trade_dates_only, [idx] * len(close_trade_dates_only), 'o', color='red', label='Close Trade Dates' if idx == 0 else "")

        # Formatting the plot
        y_labels = [f"{key[0]}-{key[1]}" for key, _ in chunk_data]
        if y_labels:
            ax.set_yticks(range(len(y_labels)))
            ax.set_yticklabels(y_labels, fontsize=10, horizontalalignment='right')

        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
        plt.xticks(rotation=45)
        plt.xlabel('Date')
        plt.title(f'Event Timelines for {plot_name}')
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from pprint import pprint

def print_trading_with_prices(dict, days_ran):
    global prices_with_market
    
    # Function to convert date strings to datetime objects
    def str_to_date(date_str):
        return datetime.strptime(date_str, '%Y-%m-%d')

    # Filter out keys with no periods or events
    filtered_data = {
        key: value for key, value in dict.items()
        if (value.get('monitoring_start_dates') or value.get('monitoring_end_dates') or
            value.get('trade_info', {}).get('open_trade_dates') or value.get('trade_info', {}).get('close_trade_dates'))
    }
    
    for key in filtered_data:        
        # Safely access trade dates
        open_trade_dates = [item[0] for item in filtered_data[key].get('trade_info', {}).get('open_trade_dates', [])]
        close_trade_dates = [item[0] for item in filtered_data[key].get('trade_info', {}).get('close_trade_dates', [])]

        # Skip processing if there are no open trade dates
        if not open_trade_dates:
            continue  # Skip if there are no open trade dates

        # Determine the start date for plotting
        first_open_trade_date = str_to_date(open_trade_dates[0]) - timedelta(days=20)  # 20 days before

        # Determine the end date for plotting
        if close_trade_dates:
            last_close_trade_date = str_to_date(close_trade_dates[-1]) + timedelta(days=20)  # 20 days after
            try:
                plot_end_loc = prices_with_market.index.get_loc(last_close_trade_date)
            except KeyError:
                # Use the closest available date
                closest_date = prices_with_market.index[prices_with_market.index.get_indexer([last_close_trade_date], method='nearest')[0]]
                plot_end_loc = prices_with_market.index.get_loc(closest_date)
        else:
            # If no close trade dates, use days_ran parameter for the end of the plot
            last_open_trade_date = str_to_date(open_trade_dates[-1])
            try:
                plot_end_loc = prices_with_market.index.get_loc(last_open_trade_date) + days_ran
            except KeyError:
                # Use the closest available date
                closest_date = prices_with_market.index[prices_with_market.index.get_indexer([last_open_trade_date], method='nearest')[0]]
                plot_end_loc = prices_with_market.index.get_loc(closest_date) + days_ran

        # Ensure plot_end_loc does not exceed the length of the DataFrame
        if plot_end_loc >= len(prices_with_market):
            plot_end_loc = len(prices_with_market) - 1

        plot_end_date = prices_with_market.index[plot_end_loc]

        # Adjust plot_start_date to ensure it is within the DataFrame
        plot_start_date = max(prices_with_market.index[0], first_open_trade_date)

        # Plot the relevant prices
        try:
            prices_with_market[[key[0], key[1]]][plot_start_date:plot_end_date].plot()
            plt.title(f"{key}")

            # Prepare trade information for display
            trades_info = []
            num_trades = max(len(open_trade_dates), len(close_trade_dates))
            for i in range(num_trades):
                open_date = open_trade_dates[i]
                try:
                    close_date = close_trade_dates[i]
                    message = filtered_data[key]['trade_info']['close_trade_dates'][i][1]
                except IndexError:
                    close_date = ''
                    message = 'Stock in trade'
                string = f'({open_date}-{close_date}) : {message}'
                trades_info.append(string)    

            # Add vertical green lines for open_trade_dates
            for date in open_trade_dates:
                plt.axvline(x=date, color='green', linestyle='--', linewidth=1)

            # Add vertical red lines for close_trade_dates
            for date in close_trade_dates:
                plt.axvline(x=date, color='red', linestyle='--', linewidth=1)

            plt.show()
            
        except KeyError as e:
            print(f"KeyError: {e} for {key}. Data may be missing.")
        except Exception as e:
            print(f"An error occurred while processing {key}: {e}")

# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

def print_spread_with_trading_charts(data_dict, days_ran):
    global prices_with_market
    
    # Function to convert date strings to datetime objects
    def str_to_date(date_str):
        if isinstance(date_str, str):
            return datetime.strptime(date_str, '%Y-%m-%d')
        return date_str  # Already a datetime object

    for key in data_dict:
        if not data_dict[key]['trade_info']['open_trade_dates'] or not data_dict[key]['monitoring_start_dates']:
            continue
        
        monitoring_start_dates = data_dict[key]['monitoring_start_dates']
        monitoring_end_dates = data_dict[key]['monitoring_end_dates']
        open_trade_dates = [day[0] for day in data_dict[key]['trade_info']['open_trade_dates']]
        close_trade_dates = [day[0] for day in data_dict[key]['trade_info']['close_trade_dates']]
        
        stock1, stock2 = key
        periods = construct_periods(open_trade_dates, close_trade_dates)
        close_trade_tuples = data_dict[key]['trade_info']['close_trade_dates']

        for period in periods:
            spread_start_date = str_to_date(period[0])  # Ensure this is a datetime object
            if len(period) > 1:
                spread_end_date = str_to_date(period[1]) if period[1] is not None else (spread_start_date + timedelta(days=days_ran))
            else:
                spread_end_date = spread_start_date + timedelta(days=days_ran)

            # Adjust the start date for plotting (5 days before)
            adjusted_start_date = spread_start_date - timedelta(days=5)
            # Adjust the end date for plotting (5 days after)
            adjusted_end_date = spread_end_date + timedelta(days=5)

            # Ensure dates are within the DataFrame range
            try:
                start_loc = prices_with_market.index.get_loc(adjusted_start_date)
            except KeyError:
                start_loc = prices_with_market.index.get_indexer([adjusted_start_date], method='nearest')[0]

            try:
                end_loc = prices_with_market.index.get_loc(adjusted_end_date)
            except KeyError:
                end_loc = prices_with_market.index.get_indexer([adjusted_end_date], method='nearest')[0]

            # Get the actual dates from the DataFrame
            actual_start_date = prices_with_market.index[start_loc]
            actual_end_date = prices_with_market.index[end_loc]

            # Get past three months data
            past_three_months_all_data = prices_with_market.iloc[max(0, start_loc - 89):start_loc + 1]
            past_three_months_data = past_three_months_all_data[[stock1, stock2]]
                
            beta = calculate_beta_for_pair(past_three_months_data, key)
            upper, lower, mean_val = get_spread_limits_for_past_months(past_three_months_data, key, beta)
            
            # Calculate spread using the order of stocks from the key
            price_data = prices_with_market[[stock1, stock2]].loc[actual_start_date:actual_end_date]
            pair_order = [stock1, stock2]  # Define the order based on the key
            spread_data = price_data[pair_order[0]] - beta * price_data[pair_order[1]]
            dates = spread_data.index
            values = spread_data.values

            # Plot the data
            plt.figure(figsize=(10, 6))
            plt.axhline(y=mean_val, color='blue', linestyle='-', linewidth=1, label='Mean for Past 3 months')
            plt.axhline(y=upper, color='red', linestyle='--', linewidth=1, label='+2 Std Dev')
            plt.axhline(y=lower, color='red', linestyle='--', linewidth=1, label='-2 Std Dev')
            plt.scatter(dates, values, c='black')

            # Add green dots for open-trade dates
            open_trade_dates_dt = [str_to_date(date[0]) for date in data_dict[key]['trade_info']['open_trade_dates']]
            for open_trade_date in open_trade_dates_dt:
                if open_trade_date in dates:
                    plt.scatter(open_trade_date, spread_data.loc[open_trade_date], color='green', s=50, label='Open Trade')

            plt.title(f"Spread data for: {key} for trade: {period}")
            plt.xlabel('Date')
            plt.ylabel('Value')
            plt.legend()
            plt.grid(True)
            plt.show()

            # Find the message
            open_date = actual_start_date.strftime('%Y-%m-%d')
            close_date = actual_end_date.strftime('%Y-%m-%d')
            message = 'Stocks currently in trade'
            for tuple in close_trade_tuples:
                if tuple[0] == close_date:
                    message = tuple[1]
            string = f'({open_date}-{close_date}) : {message}'  
            print('Trades: ') 
            print(string)

# %%
def print_all_visualizations(dict, days_ran):
    print_overall_display(dict, days_ran)
    print_trading_with_prices(dict, days_ran)
    print_spread_with_trading_charts(dict, days_ran)

# %%
# Run Main code
import pprint as pprint
num_days_to_run = 50
window_size_in_days = 180
num_liquid_stocks_to_consider = 30
results, spread_percentages = monitor_pairs(window_size_in_days, num_liquid_stocks_to_consider, num_days_to_run)
pprint.pprint(results)
print(spread_percentages)
# Out:
# ----------- Weeks Running: 0 --------------------
# ----------- Weeks Running: 1 --------------------
# Stock pair: ('SDLI', 'NRTLQ'), percentage: 4.17
# Stock pair: ('GLW', 'SEBL'), percentage: -9.01
# ----------- Weeks Running: 2 --------------------
# Stock pair: ('CMRCQ', 'BB'), percentage: -0.19
# ----------- Weeks Running: 3 --------------------
# Stock pair: ('CIEN', 'SEBL'), percentage: -1.66
# Stock pair: ('ARBA', 'ITWO'), percentage: -2.76
# Stock pair: ('AMCC', 'JNPR'), percentage: 2.52
# ----------- Weeks Running: 4 --------------------
# Stock pair: ('CSCO', 'TWX'), percentage: -2.72
# ----------- Weeks Running: 5 --------------------
# Stock pair: ('LVLT', 'MSFT'), percentage: -7.9
# Stock pair: ('NTAP', 'ITWO'), percentage: -3.3
# Stock pair: ('CIEN', 'SEBL'), percentage: 7.73
# ----------- Weeks Running: 6 --------------------
# Stock pair: ('EXTR', 'AMCC'), percentage: 0.72
# ----------- Weeks Running: 7 --------------------
# Stock pair: ('BRCM', 'ARBA'), percentage: -8.85
# Stock pair: ('PMCS', 'VRSN'), percentage: 0.22
# Stock pair: ('JNPR', 'EMC1'), percentage: 0.07
# Stock pair: ('ORCL', 'VIAV'), percentage: -8.66
# Stock pair: ('VRTS1', 'CMVT'), percentage: 3.15
# {('AMCC', 'JNPR'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-10-18'],
#                     'monitoring_start_dates': ['2000-10-09'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 3.7092920993899483,
#                     'spread_upper_limit': 111.91631767838783,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-10-18',
#                                                           'Stocks are no '
#                                                           'longer cointegrated',
#                                                           8.131950000000018)],
#                                    'open_trade_dates': [('2000-10-16',
#                                                          'Buying spread',
#                                                          -10.420169999999985,
#                                                          733.66817,
#                                                          1.93)]},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('ARBA', 'AMCC'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': [],
#                     'monitoring_start_dates': ['2000-11-28'],
#                     'should_monitor': True,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Looking for trading days'},
#  ('ARBA', 'ITWO'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-10-18'],
#                     'monitoring_start_dates': ['2000-09-28'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 792.1924741421785,
#                     'spread_upper_limit': 1951.5515829689325,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-10-18',
#                                                           'Stocks are no '
#                                                           'longer cointegrated',
#                                                           -266.87800000000004)],
#                                    'open_trade_dates': [('2000-09-28',
#                                                          'Buying spread',
#                                                          -211.74699999999996,
#                                                          2002.0030000000002,
#                                                          0.46)]},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('BRCD', 'EXTR'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': [],
#                     'monitoring_start_dates': ['2000-11-28'],
#                     'should_monitor': True,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Looking for trading days'},
#  ('BRCD', 'SEBL'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-09-28', '2000-11-28'],
#                     'monitoring_start_dates': ['2000-09-19', '2000-10-27'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -24.262304777586444,
#                     'spread_upper_limit': 6.8400164442531235,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('BRCM', 'ARBA'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-11-28'],
#                     'monitoring_start_dates': ['2000-11-07'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 278.02928812730005,
#                     'spread_upper_limit': 1050.3361774282557,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-11-28',
#                                                           'Stocks are no '
#                                                           'longer cointegrated',
#                                                           15.616999999999997)],
#                                    'open_trade_dates': [('2000-11-07',
#                                                          'Buying spread',
#                                                          32.108999999999995,
#                                                          186.459,
#                                                          0.1)]},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('CIEN', 'BEAS'): {'current_hedge_ratio': 10.38,
#                     'current_spread_mean': 19.52851733333329,
#                     'currently_trading': False,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': [],
#                     'monitoring_start_dates': ['2000-11-16'],
#                     'should_monitor': True,
#                     'spread_lower_limit': -98.11160809645321,
#                     'spread_upper_limit': 137.1686427631198,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Looking for trading days'},
#  ('CIEN', 'SEBL'): {'current_hedge_ratio': 8.49,
#                     'current_spread_mean': -96.65840366666667,
#                     'currently_trading': False,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': ['2000-10-18'],
#                     'monitoring_start_dates': ['2000-09-19', '2000-10-27'],
#                     'should_monitor': True,
#                     'spread_lower_limit': -221.55621713202842,
#                     'spread_upper_limit': 28.23940979869508,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-10-18',
#                                                           'Stocks are no '
#                                                           'longer cointegrated',
#                                                           6.751599999999939),
#                                                          ('2000-11-14',
#                                                           'Stocks mean '
#                                                           'reverted',
#                                                           -133.02632000000006)],
#                                    'open_trade_dates': [('2000-10-06',
#                                                          'Selling spread',
#                                                          -19.111799999999903,
#                                                          1566.9517999999998,
#                                                          8.6),
#                                                         ('2000-10-30',
#                                                          'Buying spread',
#                                                          -255.93462999999997,
#                                                          1525.59463,
#                                                          9.17)]},
#                     'trade_status_message': 'Looking for trading days'},
#  ('CMRCQ', 'BB'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2000-10-09'],
#                    'monitoring_start_dates': ['2000-09-28'],
#                    'should_monitor': False,
#                    'spread_lower_limit': -23.58296898559189,
#                    'spread_upper_limit': 446.4221409855919,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2000-10-09',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          -60.490920000000074)],
#                                   'open_trade_dates': [('2000-10-03',
#                                                         'Buying spread',
#                                                         -58.19207999999992,
#                                                         1235.6920799999998,
#                                                         37.76)]},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('CSCO', 'ORCL'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-11-16'],
#                     'monitoring_start_dates': ['2000-11-07'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 9.112287549836086,
#                     'spread_upper_limit': 22.438903894608355,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('CSCO', 'TWX'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': None,
#                    'monitoring_end_dates': ['2000-10-27'],
#                    'monitoring_start_dates': ['2000-10-18'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 88.23898900642078,
#                    'spread_upper_limit': 124.8886956602459,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2000-10-27',
#                                                          'One or more stocks '
#                                                          'is not liquid enough '
#                                                          'to trade',
#                                                          9.180779999999999)],
#                                   'open_trade_dates': [('2000-10-18',
#                                                         'Buying spread',
#                                                         10.84104,
#                                                         61.20096,
#                                                         0.26)]},
#                    'trade_status_message': 'Stocks not liquid enough to trade'},
#  ('CSCO', 'YHOO'): {'current_hedge_ratio': 0.22,
#                     'current_spread_mean': 48.50276588888889,
#                     'currently_trading': False,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': [],
#                     'monitoring_start_dates': ['2000-11-28'],
#                     'should_monitor': True,
#                     'spread_lower_limit': 14.885604536527126,
#                     'spread_upper_limit': 82.11992724125065,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Looking for trading days'},
#  ('DELL1', 'AMAT'): {'current_hedge_ratio': 1.27,
#                      'current_spread_mean': 3.2592859444444438,
#                      'currently_trading': False,
#                      'is_cointegrated': True,
#                      'monitoring_end_dates': [],
#                      'monitoring_start_dates': ['2000-11-28'],
#                      'should_monitor': True,
#                      'spread_lower_limit': -3.6863615835815837,
#                      'spread_upper_limit': 10.204933472470472,
#                      'trade_day_spread_position': 'unknown',
#                      'trade_info': {'close_trade_dates': [],
#                                     'open_trade_dates': []},
#                      'trade_status_message': 'Looking for trading days'},
#  ('EMC1', 'BRCD'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-11-28'],
#                     'monitoring_start_dates': ['2000-11-16'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 13.571598762895636,
#                     'spread_upper_limit': 75.62960590377102,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('EMC1', 'EXTR'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': [],
#                     'monitoring_start_dates': ['2000-11-28'],
#                     'should_monitor': True,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Looking for trading days'},
#  ('EMC1', 'GLW'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': False,
#                    'monitoring_end_dates': ['2000-09-28'],
#                    'monitoring_start_dates': ['2000-09-19'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 12.154431728617942,
#                    'spread_upper_limit': 29.571586049159833,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [],
#                                   'open_trade_dates': []},
#                    'trade_status_message': 'Stocks no longer cointegrated'},
#  ('EXTR', 'AMCC'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2000-11-16'],
#                     'monitoring_start_dates': ['2000-10-18'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 128.5103984898724,
#                     'spread_upper_limit': 375.30000151012763,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-11-16',
#                                                           'One or more stocks '
#                                                           'is not liquid '
#                                                           'enough to trade',
#                                                           -5.375)],
#                                    'open_trade_dates': [('2000-10-18',
#                                                          'Buying spread',
#                                                          -6.987160000000017,
#                                                          221.23716000000002,
#                                                          0.34)]},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('GLW', 'SEBL'): {'current_hedge_ratio': None,
#                    'current_spread_mean': None,
#                    'currently_trading': False,
#                    'is_cointegrated': False,
#                    'monitoring_end_dates': ['2000-09-28'],
#                    'monitoring_start_dates': ['2000-09-19'],
#                    'should_monitor': False,
#                    'spread_lower_limit': 16.670041103113856,
#                    'spread_upper_limit': 49.12433278577504,
#                    'trade_day_spread_position': 'unknown',
#                    'trade_info': {'close_trade_dates': [('2000-09-28',
#                                                          'Stocks are no longer '
#                                                          'cointegrated',
#                                                          -15.902729999999991)],
#                                   'open_trade_dates': [('2000-09-19',
#                                                         'Buying spread',
#                                                         -2.9328999999999894,
#                                                         143.9869,
#                                                         0.73)]},
#                    'trade_status_message': 'Stocks no longer cointegrated'},
#  ('JAVA1', 'ARBA'): {'current_hedge_ratio': 0.13,
#                      'current_spread_mean': 623.9611748333332,
#                      'currently_trading': True,
#                      'is_cointegrated': True,
#                      'monitoring_end_dates': [],
#                      'monitoring_start_dates': ['2000-11-28'],
#                      'should_monitor': True,
#                      'spread_lower_limit': 250.05671839436872,
#                      'spread_upper_limit': 997.8656312722976,
#                      'trade_day_spread_position': 'lower',
#                      'trade_info': {'close_trade_dates': [],
#                                     'open_trade_dates': [('2000-11-28',
#                                                           'Buying spread',
#                                                           114.33500000000001,
#                                                           210.665,
#                                                           0.13)]},
#                      'trade_status_message': 'Currently in trade'},
#  ('JNPR', 'BRCD'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-11-07'],
#                     'monitoring_start_dates': ['2000-10-27'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -33.438997994496475,
#                     'spread_upper_limit': 3.247388438940906,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('JNPR', 'EMC1'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-11-28'],
#                     'monitoring_start_dates': ['2000-11-16'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -99.37087167469241,
#                     'spread_upper_limit': -42.692863880863136,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-11-28',
#                                                           'Stocks are no '
#                                                           'longer cointegrated',
#                                                           -107.5274)],
#                                    'open_trade_dates': [('2000-11-21',
#                                                          'Buying spread',
#                                                          -107.7498,
#                                                          287.9858,
#                                                          2.6)]},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('JNPR', 'EXTR'): {'current_hedge_ratio': 1.25,
#                     'current_spread_mean': 38.77445694444445,
#                     'currently_trading': True,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': [],
#                     'monitoring_start_dates': ['2000-11-28'],
#                     'should_monitor': True,
#                     'spread_lower_limit': 16.473174905688197,
#                     'spread_upper_limit': 61.07573898320071,
#                     'trade_day_spread_position': 'lower',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': [('2000-11-28',
#                                                          'Buying spread',
#                                                          0.8055000000000092,
#                                                          167.53050000000002,
#                                                          1.25)]},
#                     'trade_status_message': 'Currently in trade'},
#  ('JNPR', 'SEBL'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-09-28'],
#                     'monitoring_start_dates': ['2000-09-19'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -55.521692444461884,
#                     'spread_upper_limit': -2.771236444427011,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('LVLT', 'CSCO'): {'current_hedge_ratio': 48.8,
#                     'current_spread_mean': -981.1475866666665,
#                     'currently_trading': False,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': [],
#                     'monitoring_start_dates': ['2000-11-28'],
#                     'should_monitor': True,
#                     'spread_lower_limit': -1336.6782558728496,
#                     'spread_upper_limit': -625.6169174604834,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Looking for trading days'},
#  ('LVLT', 'MSFT'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-11-07'],
#                     'monitoring_start_dates': ['2000-10-27'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -309.011762914718,
#                     'spread_upper_limit': 248.97210024805145,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-11-07',
#                                                           'Stocks are no '
#                                                           'longer cointegrated',
#                                                           -631.5981300000001)],
#                                    'open_trade_dates': [('2000-10-27',
#                                                          'Buying spread',
#                                                          -487.9966199999999,
#                                                          1819.39662,
#                                                          54.87)]},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('LVLT', 'YHOO'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-09-28'],
#                     'monitoring_start_dates': ['2000-09-19'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 88.16750478591604,
#                     'spread_upper_limit': 920.870506325195,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('NTAP', 'BEAS'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2000-11-07'],
#                     'monitoring_start_dates': ['2000-10-27'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -6.816714543917868,
#                     'spread_upper_limit': 25.705164321695662,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('NTAP', 'ITWO'): {'current_hedge_ratio': 0.04,
#                     'current_spread_mean': 1764.464014,
#                     'currently_trading': True,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': ['2000-11-07'],
#                     'monitoring_start_dates': ['2000-10-27', '2000-11-16'],
#                     'should_monitor': True,
#                     'spread_lower_limit': 1006.5302569938469,
#                     'spread_upper_limit': 2522.3977710061527,
#                     'trade_day_spread_position': 'lower',
#                     'trade_info': {'close_trade_dates': [('2000-11-07',
#                                                           'Stocks are no '
#                                                           'longer cointegrated',
#                                                           5.2760000000000105)],
#                                    'open_trade_dates': [('2000-10-27',
#                                                          'Buying spread',
#                                                          11.162999999999997,
#                                                          178.663,
#                                                          0.04),
#                                                         ('2000-11-16',
#                                                          'Buying spread',
#                                                          -5.128479999999996,
#                                                          117.49647999999999,
#                                                          0.04)]},
#                     'trade_status_message': 'Currently in trade'},
#  ('ORCL', 'VIAV'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-11-28'],
#                     'monitoring_start_dates': ['2000-11-16'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 318.1864025571531,
#                     'spread_upper_limit': 652.6436851095135,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-11-28',
#                                                           'Stocks are no '
#                                                           'longer cointegrated',
#                                                           10.34562)],
#                                    'open_trade_dates': [('2000-11-16',
#                                                          'Buying spread',
#                                                          13.097550000000004,
#                                                          31.800449999999998,
#                                                          0.03)]},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('PMCS', 'NRTLQ'): {'current_hedge_ratio': 0.22,
#                      'current_spread_mean': 585.2356817777778,
#                      'currently_trading': True,
#                      'is_cointegrated': True,
#                      'monitoring_end_dates': [],
#                      'monitoring_start_dates': ['2000-11-28'],
#                      'should_monitor': True,
#                      'spread_lower_limit': 348.5402238212574,
#                      'spread_upper_limit': 821.9311397342982,
#                      'trade_day_spread_position': 'lower',
#                      'trade_info': {'close_trade_dates': [],
#                                     'open_trade_dates': [('2000-11-28',
#                                                           'Buying spread',
#                                                           15.435839999999999,
#                                                           178.31416000000002,
#                                                           0.22)]},
#                      'trade_status_message': 'Currently in trade'},
#  ('PMCS', 'ORCL'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': False,
#                     'monitoring_end_dates': ['2000-09-28'],
#                     'monitoring_start_dates': ['2000-09-19'],
#                     'should_monitor': False,
#                     'spread_lower_limit': -142.17697189080704,
#                     'spread_upper_limit': -57.89413877585965,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks no longer cointegrated'},
#  ('PMCS', 'VRSN'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2000-11-28'],
#                     'monitoring_start_dates': ['2000-11-07'],
#                     'should_monitor': False,
#                     'spread_lower_limit': 57.69496725391389,
#                     'spread_upper_limit': 143.0644487460861,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [('2000-11-28',
#                                                           'One or more stocks '
#                                                           'is not liquid '
#                                                           'enough to trade',
#                                                           52.13644)],
#                                    'open_trade_dates': [('2000-11-07',
#                                                          'Buying spread',
#                                                          51.68428,
#                                                          204.06572,
#                                                          0.64)]},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('SCMR', 'NRTLQ'): {'current_hedge_ratio': 2.1,
#                      'current_spread_mean': -285.13854666666674,
#                      'currently_trading': False,
#                      'is_cointegrated': True,
#                      'monitoring_end_dates': [],
#                      'monitoring_start_dates': ['2000-11-28'],
#                      'should_monitor': True,
#                      'spread_lower_limit': -563.1313178013836,
#                      'spread_upper_limit': -7.14577553194988,
#                      'trade_day_spread_position': 'unknown',
#                      'trade_info': {'close_trade_dates': [],
#                                     'open_trade_dates': []},
#                      'trade_status_message': 'Looking for trading days'},
#  ('SCMR', 'VIAV'): {'current_hedge_ratio': 3.03,
#                     'current_spread_mean': -405.14245366666654,
#                     'currently_trading': False,
#                     'is_cointegrated': True,
#                     'monitoring_end_dates': [],
#                     'monitoring_start_dates': ['2000-09-19'],
#                     'should_monitor': True,
#                     'spread_lower_limit': -690.382842769374,
#                     'spread_upper_limit': -119.90206456395913,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Looking for trading days'},
#  ('SDLI', 'NRTLQ'): {'current_hedge_ratio': None,
#                      'current_spread_mean': None,
#                      'currently_trading': False,
#                      'is_cointegrated': False,
#                      'monitoring_end_dates': ['2000-09-28'],
#                      'monitoring_start_dates': ['2000-09-19'],
#                      'should_monitor': False,
#                      'spread_lower_limit': 344.14694148968965,
#                      'spread_upper_limit': 525.844051176977,
#                      'trade_day_spread_position': 'unknown',
#                      'trade_info': {'close_trade_dates': [('2000-09-28',
#                                                            'Stocks are no '
#                                                            'longer '
#                                                            'cointegrated',
#                                                            -192.33124000000004)],
#                                     'open_trade_dates': [('2000-09-19',
#                                                           'Buying spread',
#                                                           -230.49143000000004,
#                                                           914.36743,
#                                                           0.81)]},
#                      'trade_status_message': 'Stocks no longer cointegrated'},
#  ('VRSN', 'RBAK'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2000-11-16'],
#                     'monitoring_start_dates': ['2000-11-07'],
#                     'should_monitor': False,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('VRSN', 'XLNX'): {'current_hedge_ratio': None,
#                     'current_spread_mean': None,
#                     'currently_trading': False,
#                     'is_cointegrated': None,
#                     'monitoring_end_dates': ['2000-11-16'],
#                     'monitoring_start_dates': ['2000-11-07'],
#                     'should_monitor': False,
#                     'spread_lower_limit': None,
#                     'spread_upper_limit': None,
#                     'trade_day_spread_position': 'unknown',
#                     'trade_info': {'close_trade_dates': [],
#                                    'open_trade_dates': []},
#                     'trade_status_message': 'Stocks not liquid enough to '
#                                             'trade'},
#  ('VRTS1', 'CMVT'): {'current_hedge_ratio': None,
#                      'current_spread_mean': None,
#                      'currently_trading': False,
#                      'is_cointegrated': None,
#                      'monitoring_end_dates': ['2000-11-28'],
#                      'monitoring_start_dates': ['2000-11-16'],
#                      'should_monitor': False,
#                      'spread_lower_limit': -28.411426009536278,
#                      'spread_upper_limit': 17.45836156509182,
#                      'trade_day_spread_position': 'unknown',
#                      'trade_info': {'close_trade_dates': [('2000-11-28',
#                                                            'One or more stocks '
#                                                            'is not liquid '
#                                                            'enough to trade',
#                                                            -25.017599999999987)],
#                                     'open_trade_dates': [('2000-11-17',
#                                                           'Buying spread',
#                                                           -32.99980000000002,
#                                                           253.24980000000002,
#                                                           2.6)]},
#                      'trade_status_message': 'Stocks not liquid enough to '
#                                              'trade'},
#  ('VTSS', 'VRTS1'): {'current_hedge_ratio': None,
#                      'current_spread_mean': None,
#                      'currently_trading': False,
#                      'is_cointegrated': None,
#                      'monitoring_end_dates': ['2000-10-18'],
#                      'monitoring_start_dates': ['2000-10-09'],
#                      'should_monitor': False,
#                      'spread_lower_limit': -400.4746582593565,
#                      'spread_upper_limit': 488.2266182593563,
#                      'trade_day_spread_position': 'unknown',
#                      'trade_info': {'close_trade_dates': [],
#                                     'open_trade_dates': []},
#                      'trade_status_message': 'Stocks not liquid enough to '
#                                              'trade'}}
# [4.17, -9.01, -0.19, -1.66, -2.76, 2.52, -2.72, -7.9, -3.3, 7.73, 0.72, -8.85, 0.22, 0.07, -8.66, 3.15]

# %%
# Visualizations 
#print_all_visualizations(results, 50)
#print_overall_display(results, 50)
#print_trading_with_prices(results, 50)
#print_spread_with_trading_charts(results, 50)
